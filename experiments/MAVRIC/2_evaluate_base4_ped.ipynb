# %% [markdown]
# #EVALUATING DATA FOR MULTIPLE DATASETS to fit NuScene format for Trajectron++

# %% [markdown]
# ## Mount the drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ## Install necessary requirements for evaluation

# %%
# %cd /content/drive/My Drive/Colab Notebooks/Trajectron++
# !pip install -r requirements.txt

# %% [markdown]
# ## Process the data

# %%
# %cd /content/drive/My Drive/Colab Notebooks/Trajectron++/experiments/MAVRIC
# Out:
# /content/drive/My Drive/Colab Notebooks/Trajectron++/experiments/MAVRIC

# %% [markdown]
# ### NuScenes (Done)
# num_samples = 20

# %%
# !python evaluate_MAVRIC.py --model models/vel_ee --checkpoint=12 --data ./data/processed/nuScenes/nuScenes_01_full.pkl --output_path ./data/results/BASE/4sec/PEDESTRIAN/nuScenes/01 --output_tag vel_ee --node_type PEDESTRIAN --prediction_horizon 4
# !python evaluate_MAVRIC.py --model models/vel_ee --checkpoint=12 --data ./data/processed/nuScenes/nuScenes_02_full.pkl --output_path ./data/results/BASE/4sec/PEDESTRIAN/nuScenes/02 --output_tag vel_ee --node_type PEDESTRIAN --prediction_horizon 4
# !python evaluate_MAVRIC.py --model models/vel_ee --checkpoint=12 --data ./data/processed/nuScenes/nuScenes_03_full.pkl --output_path ./data/results/BASE/4sec/PEDESTRIAN/nuScenes/03 --output_tag vel_ee --node_type PEDESTRIAN --prediction_horizon 4
# !python evaluate_MAVRIC.py --model models/vel_ee --checkpoint=12 --data ./data/processed/nuScenes/nuScenes_04_full.pkl --output_path ./data/results/BASE/4sec/PEDESTRIAN/nuScenes/04 --output_tag vel_ee --node_type PEDESTRIAN --prediction_horizon 4
# !python evaluate_MAVRIC.py --model models/vel_ee --checkpoint=12 --data ./data/processed/nuScenes/nuScenes_05_full.pkl --output_path ./data/results/BASE/4sec/PEDESTRIAN/nuScenes/05 --output_tag vel_ee --node_type PEDESTRIAN --prediction_horizon 4
# !python evaluate_MAVRIC.py --model models/vel_ee --checkpoint=12 --data ./data/processed/nuScenes/nuScenes_06_full.pkl --output_path ./data/results/BASE/4sec/PEDESTRIAN/nuScenes/06 --output_tag vel_ee --node_type PEDESTRIAN --prediction_horizon 4
# !python evaluate_MAVRIC.py --model models/vel_ee --checkpoint=12 --data ./data/processed/nuScenes/nuScenes_07_full.pkl --output_path ./data/results/BASE/4sec/PEDESTRIAN/nuScenes/07 --output_tag vel_ee --node_type PEDESTRIAN --prediction_horizon 4
# !python evaluate_MAVRIC.py --model models/vel_ee --checkpoint=12 --data ./data/processed/nuScenes/nuScenes_08_full.pkl --output_path ./data/results/BASE/4sec/PEDESTRIAN/nuScenes/08 --output_tag vel_ee --node_type PEDESTRIAN --prediction_horizon 4
# !python evaluate_MAVRIC.py --model models/vel_ee --checkpoint=12 --data ./data/processed/nuScenes/nuScenes_09_full.pkl --output_path ./data/results/BASE/4sec/PEDESTRIAN/nuScenes/09 --output_tag vel_ee --node_type PEDESTRIAN --prediction_horizon 4
# !python evaluate_MAVRIC.py --model models/vel_ee --checkpoint=12 --data ./data/processed/nuScenes/nuScenes_10_full.pkl --output_path ./data/results/BASE/4sec/PEDESTRIAN/nuScenes/10 --output_tag vel_ee --node_type PEDESTRIAN --prediction_horizon 4
# Out:
# Loading from models/vel_ee/model_registrar-12.pt
# Loaded!
#
# -- Preparing Node Graph
# 100% 85/85 [00:01<00:00, 51.26it/s]
# Prediction Horizon: 4
# -- Evaluating GMM Z Mode (Most Likely)
# 100% 85/85 [00:38<00:00,  2.20it/s]
# 4.161981647400946
# -- Evaluating Full
# 100% 85/85 [01:37<00:00,  1.15s/it]
#
# Loading from models/vel_ee/model_registrar-12.pt
# Loaded!
#
# -- Preparing Node Graph
# 100% 85/85 [00:02<00:00, 34.06it/s]
# Prediction Horizon: 4
# -- Evaluating GMM Z Mode (Most Likely)
# 100% 85/85 [01:07<00:00,  1.27it/s]
# 4.140674655882485
# -- Evaluating Full
# 100% 85/85 [02:28<00:00,  1.75s/it]
#
# Loading from models/vel_ee/model_registrar-12.pt
# Loaded!
#
# -- Preparing Node Graph
# 100% 85/85 [00:02<00:00, 33.88it/s]
# Prediction Horizon: 4
# -- Evaluating GMM Z Mode (Most Likely)
# 100% 85/85 [00:45<00:00,  1.86it/s]
# 2.584110278369939
# -- Evaluating Full
# 100% 85/85 [01:54<00:00,  1.35s/it]
#
# Loading from models/vel_ee/model_registrar-12.pt
# Loaded!
#
# ...

# %% [markdown]
# ### Lyft (Done)

# %%
# !python evaluate_MAVRIC.py --model models/vel_ee --checkpoint=12 --data ./data/processed/Lyft/Lyft_1_full.pkl --output_path ./data/results/BASE/4sec/PEDESTRIAN/Lyft/1 --output_tag vel_ee --node_type PEDESTRIAN --prediction_horizon 4
# !python evaluate_MAVRIC.py --model models/vel_ee --checkpoint=12 --data ./data/processed/Lyft/Lyft_2_full.pkl --output_path ./data/results/BASE/4sec/PEDESTRIAN/Lyft/2 --output_tag vel_ee --node_type PEDESTRIAN --prediction_horizon 4
# Out:
# Loading from models/vel_ee/model_registrar-12.pt
# Loaded!
#
# -- Preparing Node Graph
# 100% 90/90 [00:04<00:00, 19.88it/s]
# Prediction Horizon: 4
# -- Evaluating GMM Z Mode (Most Likely)
# 100% 90/90 [01:59<00:00,  1.33s/it]
# 8.841246744828723
# -- Evaluating Full
# 100% 90/90 [06:04<00:00,  4.05s/it]
#
# Loading from models/vel_ee/model_registrar-12.pt
# Loaded!
#
# -- Preparing Node Graph
# 100% 90/90 [00:03<00:00, 23.32it/s]
# Prediction Horizon: 4
# -- Evaluating GMM Z Mode (Most Likely)
# 100% 90/90 [01:44<00:00,  1.16s/it]
# /usr/local/lib/python3.6/dist-packages/numpy/core/fromnumeric.py:3118: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /usr/local/lib/python3.6/dist-packages/numpy/core/_methods.py:85: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# nan
# -- Evaluating Full
# 100% 90/90 [05:29<00:00,  3.66s/it]

# %% [markdown]
# ### Argo (Done)

# %%
# !python evaluate_MAVRIC.py --model models/vel_ee --checkpoint=12 --data ./data/processed/Argoverse/Argoverse_1_full.pkl --output_path ./data/results/BASE/4sec/PEDESTRIAN/Argoverse/1 --output_tag vel_ee --node_type PEDESTRIAN --prediction_horizon 4
# !python evaluate_MAVRIC.py --model models/vel_ee --checkpoint=12 --data ./data/processed/Argoverse/Argoverse_2_full.pkl --output_path ./data/results/BASE/4sec/PEDESTRIAN/Argoverse/2 --output_tag vel_ee --node_type PEDESTRIAN --prediction_horizon 4
# !python evaluate_MAVRIC.py --model models/vel_ee --checkpoint=12 --data ./data/processed/Argoverse/Argoverse_3_full.pkl --output_path ./data/results/BASE/4sec/PEDESTRIAN/Argoverse/3 --output_tag vel_ee --node_type PEDESTRIAN --prediction_horizon 4
# !python evaluate_MAVRIC.py --model models/vel_ee --checkpoint=12 --data ./data/processed/Argoverse/Argoverse_4_full.pkl --output_path ./data/results/BASE/4sec/PEDESTRIAN/Argoverse/4 --output_tag vel_ee --node_type PEDESTRIAN --prediction_horizon 4
# Out:
# Loading from models/vel_ee/model_registrar-12.pt
# Loaded!
#
# -- Preparing Node Graph
# 100% 20/20 [00:00<00:00, 27.95it/s]
# Prediction Horizon: 4
# -- Evaluating GMM Z Mode (Most Likely)
# 100% 20/20 [00:37<00:00,  1.89s/it]
# 0.13384299724310597
# -- Evaluating Full
# 100% 20/20 [02:01<00:00,  6.09s/it]
#
# Loading from models/vel_ee/model_registrar-12.pt
# Loaded!
#
# -- Preparing Node Graph
# 100% 20/20 [00:00<00:00, 25.53it/s]
# Prediction Horizon: 4
# -- Evaluating GMM Z Mode (Most Likely)
# 100% 20/20 [00:36<00:00,  1.82s/it]
# /usr/local/lib/python3.6/dist-packages/numpy/core/fromnumeric.py:3118: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /usr/local/lib/python3.6/dist-packages/numpy/core/_methods.py:85: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# nan
# -- Evaluating Full
# 100% 20/20 [02:03<00:00,  6.19s/it]
#
# Loading from models/vel_ee/model_registrar-12.pt
# Loaded!
#
# -- Preparing Node Graph
# ...

# %% [markdown]
# ### Waymo (Done)

# %%
# !python evaluate_MAVRIC.py --model models/vel_ee --checkpoint=12 --data ./data/processed/Waymo/Waymo_0000_full.pkl --output_path ./data/results/BASE/4sec/PEDESTRIAN/Waymo/0000 --output_tag vel_ee --node_type PEDESTRIAN --prediction_horizon 4
# !python evaluate_MAVRIC.py --model models/vel_ee --checkpoint=12 --data ./data/processed/Waymo/Waymo_0001_full.pkl --output_path ./data/results/BASE/4sec/PEDESTRIAN/Waymo/0001 --output_tag vel_ee --node_type PEDESTRIAN --prediction_horizon 4
# !python evaluate_MAVRIC.py --model models/vel_ee --checkpoint=12 --data ./data/processed/Waymo/Waymo_0002_full.pkl --output_path ./data/results/BASE/4sec/PEDESTRIAN/Waymo/0002 --output_tag vel_ee --node_type PEDESTRIAN --prediction_horizon 4
# !python evaluate_MAVRIC.py --model models/vel_ee --checkpoint=12 --data ./data/processed/Waymo/Waymo_0003_full.pkl --output_path ./data/results/BASE/4sec/PEDESTRIAN/Waymo/0003 --output_tag vel_ee --node_type PEDESTRIAN --prediction_horizon 4
# !python evaluate_MAVRIC.py --model models/vel_ee --checkpoint=12 --data ./data/processed/Waymo/Waymo_0004_full.pkl --output_path ./data/results/BASE/4sec/PEDESTRIAN/Waymo/0004 --output_tag vel_ee --node_type PEDESTRIAN --prediction_horizon 4
# !python evaluate_MAVRIC.py --model models/vel_ee --checkpoint=12 --data ./data/processed/Waymo/Waymo_0005_full.pkl --output_path ./data/results/BASE/4sec/PEDESTRIAN/Waymo/0005 --output_tag vel_ee --node_type PEDESTRIAN --prediction_horizon 4
# !python evaluate_MAVRIC.py --model models/vel_ee --checkpoint=12 --data ./data/processed/Waymo/Waymo_0006_full.pkl --output_path ./data/results/BASE/4sec/PEDESTRIAN/Waymo/0006 --output_tag vel_ee --node_type PEDESTRIAN --prediction_horizon 4
# !python evaluate_MAVRIC.py --model models/vel_ee --checkpoint=12 --data ./data/processed/Waymo/Waymo_0007_full.pkl --output_path ./data/results/BASE/4sec/PEDESTRIAN/Waymo/0007 --output_tag vel_ee --node_type PEDESTRIAN --prediction_horizon 4
# !python evaluate_MAVRIC.py --model models/vel_ee --checkpoint=12 --data ./data/processed/Waymo/Waymo_0008_full.pkl --output_path ./data/results/BASE/4sec/PEDESTRIAN/Waymo/0008 --output_tag vel_ee --node_type PEDESTRIAN --prediction_horizon 4
# !python evaluate_MAVRIC.py --model models/vel_ee --checkpoint=12 --data ./data/processed/Waymo/Waymo_0009_full.pkl --output_path ./data/results/BASE/4sec/PEDESTRIAN/Waymo/0009 --output_tag vel_ee --node_type PEDESTRIAN --prediction_horizon 4
# !python evaluate_MAVRIC.py --model models/vel_ee --checkpoint=12 --data ./data/processed/Waymo/Waymo_0010_full.pkl --output_path ./data/results/BASE/4sec/PEDESTRIAN/Waymo/0010 --output_tag vel_ee --node_type PEDESTRIAN --prediction_horizon 4
# !python evaluate_MAVRIC.py --model models/vel_ee --checkpoint=12 --data ./data/processed/Waymo/Waymo_0011_full.pkl --output_path ./data/results/BASE/46sec/PEDESTRIAN/Waymo/0011 --output_tag vel_ee --node_type PEDESTRIAN --prediction_horizon 4
# !python evaluate_MAVRIC.py --model models/vel_ee --checkpoint=12 --data ./data/processed/Waymo/Waymo_0012_full.pkl --output_path ./data/results/BASE/4sec/PEDESTRIAN/Waymo/0012 --output_tag vel_ee --node_type PEDESTRIAN --prediction_horizon 4
# !python evaluate_MAVRIC.py --model models/vel_ee --checkpoint=12 --data ./data/processed/Waymo/Waymo_0013_full.pkl --output_path ./data/results/BASE/4sec/PEDESTRIAN/Waymo/0013 --output_tag vel_ee --node_type PEDESTRIAN --prediction_horizon 4
# !python evaluate_MAVRIC.py --model models/vel_ee --checkpoint=12 --data ./data/processed/Waymo/Waymo_0014_full.pkl --output_path ./data/results/BASE/4sec/PEDESTRIAN/Waymo/0014 --output_tag vel_ee --node_type PEDESTRIAN --prediction_horizon 4
# !python evaluate_MAVRIC.py --model models/vel_ee --checkpoint=12 --data ./data/processed/Waymo/Waymo_0015_full.pkl --output_path ./data/results/BASE/4sec/PEDESTRIAN/Waymo/0015 --output_tag vel_ee --node_type PEDESTRIAN --prediction_horizon 4
# !python evaluate_MAVRIC.py --model models/vel_ee --checkpoint=12 --data ./data/processed/Waymo/Waymo_0016_full.pkl --output_path ./data/results/BASE/4sec/PEDESTRIAN/Waymo/0016 --output_tag vel_ee --node_type PEDESTRIAN --prediction_horizon 4
# !python evaluate_MAVRIC.py --model models/vel_ee --checkpoint=12 --data ./data/processed/Waymo/Waymo_0017_full.pkl --output_path ./data/results/BASE/4sec/PEDESTRIAN/Waymo/0017 --output_tag vel_ee --node_type PEDESTRIAN --prediction_horizon 4
# !python evaluate_MAVRIC.py --model models/vel_ee --checkpoint=12 --data ./data/processed/Waymo/Waymo_0018_full.pkl --output_path ./data/results/BASE/4sec/PEDESTRIAN/Waymo/0018 --output_tag vel_ee --node_type PEDESTRIAN --prediction_horizon 4
# !python evaluate_MAVRIC.py --model models/vel_ee --checkpoint=12 --data ./data/processed/Waymo/Waymo_0019_full.pkl --output_path ./data/results/BASE/4sec/PEDESTRIAN/Waymo/0019 --output_tag vel_ee --node_type PEDESTRIAN --prediction_horizon 4
# !python evaluate_MAVRIC.py --model models/vel_ee --checkpoint=12 --data ./data/processed/Waymo/Waymo_0020_full.pkl --output_path ./data/results/BASE/4sec/PEDESTRIAN/Waymo/0020 --output_tag vel_ee --node_type PEDESTRIAN --prediction_horizon 4
# !python evaluate_MAVRIC.py --model models/vel_ee --checkpoint=12 --data ./data/processed/Waymo/Waymo_0021_full.pkl --output_path ./data/results/BASE/4sec/PEDESTRIAN/Waymo/0021 --output_tag vel_ee --node_type PEDESTRIAN --prediction_horizon 4
# !python evaluate_MAVRIC.py --model models/vel_ee --checkpoint=12 --data ./data/processed/Waymo/Waymo_0022_full.pkl --output_path ./data/results/BASE/4sec/PEDESTRIAN/Waymo/0022 --output_tag vel_ee --node_type PEDESTRIAN --prediction_horizon 4
# !python evaluate_MAVRIC.py --model models/vel_ee --checkpoint=12 --data ./data/processed/Waymo/Waymo_0023_full.pkl --output_path ./data/results/BASE/4sec/PEDESTRIAN/Waymo/0023 --output_tag vel_ee --node_type PEDESTRIAN --prediction_horizon 4
# !python evaluate_MAVRIC.py --model models/vel_ee --checkpoint=12 --data ./data/processed/Waymo/Waymo_0024_full.pkl --output_path ./data/results/BASE/4sec/PEDESTRIAN/Waymo/0024 --output_tag vel_ee --node_type PEDESTRIAN --prediction_horizon 4
# !python evaluate_MAVRIC.py --model models/vel_ee --checkpoint=12 --data ./data/processed/Waymo/Waymo_0025_full.pkl --output_path ./data/results/BASE/4sec/PEDESTRIAN/Waymo/0025 --output_tag vel_ee --node_type PEDESTRIAN --prediction_horizon 4
# !python evaluate_MAVRIC.py --model models/vel_ee --checkpoint=12 --data ./data/processed/Waymo/Waymo_0026_full.pkl --output_path ./data/results/BASE/4sec/PEDESTRIAN/Waymo/0026 --output_tag vel_ee --node_type PEDESTRIAN --prediction_horizon 4
# !python evaluate_MAVRIC.py --model models/vel_ee --checkpoint=12 --data ./data/processed/Waymo/Waymo_0027_full.pkl --output_path ./data/results/BASE/4sec/PEDESTRIAN/Waymo/0027 --output_tag vel_ee --node_type PEDESTRIAN --prediction_horizon 4
# !python evaluate_MAVRIC.py --model models/vel_ee --checkpoint=12 --data ./data/processed/Waymo/Waymo_0028_full.pkl --output_path ./data/results/BASE/4sec/PEDESTRIAN/Waymo/0028 --output_tag vel_ee --node_type PEDESTRIAN --prediction_horizon 4
# !python evaluate_MAVRIC.py --model models/vel_ee --checkpoint=12 --data ./data/processed/Waymo/Waymo_0029_full.pkl --output_path ./data/results/BASE/4sec/PEDESTRIAN/Waymo/0029 --output_tag vel_ee --node_type PEDESTRIAN --prediction_horizon 4
# !python evaluate_MAVRIC.py --model models/vel_ee --checkpoint=12 --data ./data/processed/Waymo/Waymo_0030_full.pkl --output_path ./data/results/BASE/4sec/PEDESTRIAN/Waymo/0030 --output_tag vel_ee --node_type PEDESTRIAN --prediction_horizon 4
# Out:
# Loading from models/vel_ee/model_registrar-12.pt
# Loaded!
#
# -- Preparing Node Graph
# 100% 24/24 [00:00<00:00, 30.09it/s]
# Prediction Horizon: 4
# -- Evaluating GMM Z Mode (Most Likely)
# 100% 24/24 [01:22<00:00,  3.43s/it]
# 3.2256494616079845
# -- Evaluating Full
# 100% 24/24 [03:31<00:00,  8.82s/it]
#
# Loading from models/vel_ee/model_registrar-12.pt
# Loaded!
#
# -- Preparing Node Graph
# 100% 24/24 [00:08<00:00,  2.96it/s]
# Prediction Horizon: 4
# -- Evaluating GMM Z Mode (Most Likely)
# 100% 24/24 [04:21<00:00, 10.89s/it]
# 0.20823316040072046
# -- Evaluating Full
# 100% 24/24 [09:16<00:00, 23.17s/it]
#
# Loading from models/vel_ee/model_registrar-12.pt
# Loaded!
#
# -- Preparing Node Graph
# 100% 25/25 [00:07<00:00,  3.26it/s]
# Prediction Horizon: 4
# -- Evaluating GMM Z Mode (Most Likely)
# 100% 25/25 [03:18<00:00,  7.94s/it]
# 0.17098649932015542
# -- Evaluating Full
# 100% 25/25 [08:13<00:00, 19.76s/it]
#
# Loading from models/vel_ee/model_registrar-12.pt
# Loaded!
# ...
