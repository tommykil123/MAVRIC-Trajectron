# %% [markdown]
# #EVALUATING DATA FOR MULTIPLE DATASETS to fit NuScene format for Trajectron++

# %% [markdown]
# ## Mount the drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ## Install necessary requirements for evaluation

# %%
# %cd /content/drive/My Drive/Colab Notebooks/Trajectron++
# !pip install -r requirements.txt

# %% [markdown]
# ## Process the data

# %%
# %cd /content/drive/My Drive/Colab Notebooks/Trajectron++/experiments/MAVRIC
# Out:
# /content/drive/My Drive/Colab Notebooks/Trajectron++/experiments/MAVRIC

# %% [markdown]
# ### NuScenes (Done)
# num_samples = 20

# %%
# !python evaluate_MAVRIC.py --model models/int_ee --checkpoint=12 --data ./data/processed/nuScenes/nuScenes_01_full.pkl --output_path ./data/results/DYNAMICS_INTEGRATION/4sec/VEHICLE/nuScenes/01 --output_tag int_ee --node_type VEHICLE --prediction_horizon 4
# !python evaluate_MAVRIC.py --model models/int_ee --checkpoint=12 --data ./data/processed/nuScenes/nuScenes_02_full.pkl --output_path ./data/results/DYNAMICS_INTEGRATION/4sec/VEHICLE/nuScenes/02 --output_tag int_ee --node_type VEHICLE --prediction_horizon 4
# !python evaluate_MAVRIC.py --model models/int_ee --checkpoint=12 --data ./data/processed/nuScenes/nuScenes_03_full.pkl --output_path ./data/results/DYNAMICS_INTEGRATION/4sec/VEHICLE/nuScenes/03 --output_tag int_ee --node_type VEHICLE --prediction_horizon 4
# !python evaluate_MAVRIC.py --model models/int_ee --checkpoint=12 --data ./data/processed/nuScenes/nuScenes_04_full.pkl --output_path ./data/results/DYNAMICS_INTEGRATION/4sec/VEHICLE/nuScenes/04 --output_tag int_ee --node_type VEHICLE --prediction_horizon 4
# !python evaluate_MAVRIC.py --model models/int_ee --checkpoint=12 --data ./data/processed/nuScenes/nuScenes_05_full.pkl --output_path ./data/results/DYNAMICS_INTEGRATION/4sec/VEHICLE/nuScenes/05 --output_tag int_ee --node_type VEHICLE --prediction_horizon 4
# !python evaluate_MAVRIC.py --model models/int_ee --checkpoint=12 --data ./data/processed/nuScenes/nuScenes_06_full.pkl --output_path ./data/results/DYNAMICS_INTEGRATION/4sec/VEHICLE/nuScenes/06 --output_tag int_ee --node_type VEHICLE --prediction_horizon 4
# !python evaluate_MAVRIC.py --model models/int_ee --checkpoint=12 --data ./data/processed/nuScenes/nuScenes_07_full.pkl --output_path ./data/results/DYNAMICS_INTEGRATION/4sec/VEHICLE/nuScenes/07 --output_tag int_ee --node_type VEHICLE --prediction_horizon 4
# !python evaluate_MAVRIC.py --model models/int_ee --checkpoint=12 --data ./data/processed/nuScenes/nuScenes_08_full.pkl --output_path ./data/results/DYNAMICS_INTEGRATION/4sec/VEHICLE/nuScenes/08 --output_tag int_ee --node_type VEHICLE --prediction_horizon 4
# !python evaluate_MAVRIC.py --model models/int_ee --checkpoint=12 --data ./data/processed/nuScenes/nuScenes_09_full.pkl --output_path ./data/results/DYNAMICS_INTEGRATION/4sec/VEHICLE/nuScenes/09 --output_tag int_ee --node_type VEHICLE --prediction_horizon 4
# !python evaluate_MAVRIC.py --model models/int_ee --checkpoint=12 --data ./data/processed/nuScenes/nuScenes_10_full.pkl --output_path ./data/results/DYNAMICS_INTEGRATION/4sec/VEHICLE/nuScenes/10 --output_tag int_ee --node_type VEHICLE --prediction_horizon 4
# Out:
# Loading from models/int_ee/model_registrar-12.pt
# Loaded!
#
# -- Preparing Node Graph
# 100% 85/85 [00:01<00:00, 55.99it/s]
# Prediction Horizon: 4
# -- Evaluating GMM Z Mode (Most Likely)
# 100% 85/85 [00:31<00:00,  2.70it/s]
# 1.5029291685361126
# -- Evaluating Full
# 100% 85/85 [01:16<00:00,  1.12it/s]
#
# Loading from models/int_ee/model_registrar-12.pt
# Loaded!
#
# -- Preparing Node Graph
# 100% 85/85 [00:02<00:00, 35.12it/s]
# Prediction Horizon: 4
# -- Evaluating GMM Z Mode (Most Likely)
# 100% 85/85 [00:50<00:00,  1.69it/s]
# 1.4432873854600414
# -- Evaluating Full
# 100% 85/85 [01:52<00:00,  1.32s/it]
#
# Loading from models/int_ee/model_registrar-12.pt
# Loaded!
#
# -- Preparing Node Graph
# 100% 85/85 [00:02<00:00, 33.85it/s]
# Prediction Horizon: 4
# -- Evaluating GMM Z Mode (Most Likely)
# 100% 85/85 [00:35<00:00,  2.39it/s]
# 1.3406410520932475
# -- Evaluating Full
# 100% 85/85 [01:29<00:00,  1.05s/it]
#
# Loading from models/int_ee/model_registrar-12.pt
# Loaded!
#
# ...

# %% [markdown]
# ### Lyft (Done)

# %%
# !python evaluate_MAVRIC.py --model models/int_ee --checkpoint=12 --data ./data/processed/Lyft/Lyft_1_full.pkl --output_path ./data/results/DYNAMICS_INTEGRATION/4sec/VEHICLE/Lyft/1 --output_tag int_ee --node_type VEHICLE --prediction_horizon 4
# !python evaluate_MAVRIC.py --model models/int_ee --checkpoint=12 --data ./data/processed/Lyft/Lyft_2_full.pkl --output_path ./data/results/DYNAMICS_INTEGRATION/4sec/VEHICLE/Lyft/2 --output_tag int_ee --node_type VEHICLE --prediction_horizon 4
# Out:
# Loading from models/int_ee/model_registrar-12.pt
# Loaded!
#
# -- Preparing Node Graph
# 100% 90/90 [00:04<00:00, 20.41it/s]
# Prediction Horizon: 4
# -- Evaluating GMM Z Mode (Most Likely)
# 100% 90/90 [01:38<00:00,  1.10s/it]
# 0.2361262894453755
# -- Evaluating Full
# 100% 90/90 [04:51<00:00,  3.24s/it]
#
# Loading from models/int_ee/model_registrar-12.pt
# Loaded!
#
# -- Preparing Node Graph
# 100% 90/90 [00:03<00:00, 23.38it/s]
# Prediction Horizon: 4
# -- Evaluating GMM Z Mode (Most Likely)
# 100% 90/90 [01:28<00:00,  1.02it/s]
# 0.23650453529553914
# -- Evaluating Full
# 100% 90/90 [04:29<00:00,  2.99s/it]

# %% [markdown]
# ### Argo (Done)

# %%
# !python evaluate_MAVRIC.py --model models/int_ee --checkpoint=12 --data ./data/processed/Argoverse/Argoverse_1_full.pkl --output_path ./data/results/DYNAMICS_INTEGRATION/4sec/VEHICLE/Argoverse/1 --output_tag int_ee --node_type VEHICLE --prediction_horizon 4
# !python evaluate_MAVRIC.py --model models/int_ee --checkpoint=12 --data ./data/processed/Argoverse/Argoverse_2_full.pkl --output_path ./data/results/DYNAMICS_INTEGRATION/4sec/VEHICLE/Argoverse/2 --output_tag int_ee --node_type VEHICLE --prediction_horizon 4
# !python evaluate_MAVRIC.py --model models/int_ee --checkpoint=12 --data ./data/processed/Argoverse/Argoverse_3_full.pkl --output_path ./data/results/DYNAMICS_INTEGRATION/4sec/VEHICLE/Argoverse/3 --output_tag int_ee --node_type VEHICLE --prediction_horizon 4
# !python evaluate_MAVRIC.py --model models/int_ee --checkpoint=12 --data ./data/processed/Argoverse/Argoverse_4_full.pkl --output_path ./data/results/DYNAMICS_INTEGRATION/4sec/VEHICLE/Argoverse/4 --output_tag int_ee --node_type VEHICLE --prediction_horizon 4
# Out:
# Loading from models/int_ee/model_registrar-12.pt
# Loaded!
#
# -- Preparing Node Graph
# 100% 20/20 [00:00<00:00, 29.66it/s]
# Prediction Horizon: 4
# -- Evaluating GMM Z Mode (Most Likely)
# 100% 20/20 [00:33<00:00,  1.66s/it]
# 0.1355678758558974
# -- Evaluating Full
# 100% 20/20 [01:40<00:00,  5.03s/it]
#
# Loading from models/int_ee/model_registrar-12.pt
# Loaded!
#
# -- Preparing Node Graph
# 100% 20/20 [00:00<00:00, 29.72it/s]
# Prediction Horizon: 4
# -- Evaluating GMM Z Mode (Most Likely)
# 100% 20/20 [00:28<00:00,  1.43s/it]
# 0.14345042291372204
# -- Evaluating Full
# 100% 20/20 [01:32<00:00,  4.61s/it]
#
# Loading from models/int_ee/model_registrar-12.pt
# Loaded!
#
# -- Preparing Node Graph
# 100% 20/20 [00:00<00:00, 39.20it/s]
# Prediction Horizon: 4
# -- Evaluating GMM Z Mode (Most Likely)
# 100% 20/20 [00:21<00:00,  1.10s/it]
# 0.140697567209796
# -- Evaluating Full
# 100% 20/20 [01:14<00:00,  3.74s/it]
#
# Loading from models/int_ee/model_registrar-12.pt
# Loaded!
#
# ...

# %% [markdown]
# ### Waymo (Done)

# %%
# !python evaluate_MAVRIC.py --model models/int_ee --checkpoint=12 --data ./data/processed/Waymo/Waymo_0000_full.pkl --output_path ./data/results/DYNAMICS_INTEGRATION/4sec/VEHICLE/Waymo/0000 --output_tag int_ee --node_type VEHICLE --prediction_horizon 4
# !python evaluate_MAVRIC.py --model models/int_ee --checkpoint=12 --data ./data/processed/Waymo/Waymo_0001_full.pkl --output_path ./data/results/DYNAMICS_INTEGRATION/4sec/VEHICLE/Waymo/0001 --output_tag int_ee --node_type VEHICLE --prediction_horizon 4
# !python evaluate_MAVRIC.py --model models/int_ee --checkpoint=12 --data ./data/processed/Waymo/Waymo_0002_full.pkl --output_path ./data/results/DYNAMICS_INTEGRATION/4sec/VEHICLE/Waymo/0002 --output_tag int_ee --node_type VEHICLE --prediction_horizon 4
# !python evaluate_MAVRIC.py --model models/int_ee --checkpoint=12 --data ./data/processed/Waymo/Waymo_0003_full.pkl --output_path ./data/results/DYNAMICS_INTEGRATION/4sec/VEHICLE/Waymo/0003 --output_tag int_ee --node_type VEHICLE --prediction_horizon 4
# !python evaluate_MAVRIC.py --model models/int_ee --checkpoint=12 --data ./data/processed/Waymo/Waymo_0004_full.pkl --output_path ./data/results/DYNAMICS_INTEGRATION/4sec/VEHICLE/Waymo/0004 --output_tag int_ee --node_type VEHICLE --prediction_horizon 4
# !python evaluate_MAVRIC.py --model models/int_ee --checkpoint=12 --data ./data/processed/Waymo/Waymo_0005_full.pkl --output_path ./data/results/DYNAMICS_INTEGRATION/4sec/VEHICLE/Waymo/0005 --output_tag int_ee --node_type VEHICLE --prediction_horizon 4
# !python evaluate_MAVRIC.py --model models/int_ee --checkpoint=12 --data ./data/processed/Waymo/Waymo_0006_full.pkl --output_path ./data/results/DYNAMICS_INTEGRATION/4sec/VEHICLE/Waymo/0006 --output_tag int_ee --node_type VEHICLE --prediction_horizon 4
# !python evaluate_MAVRIC.py --model models/int_ee --checkpoint=12 --data ./data/processed/Waymo/Waymo_0007_full.pkl --output_path ./data/results/DYNAMICS_INTEGRATION/4sec/VEHICLE/Waymo/0007 --output_tag int_ee --node_type VEHICLE --prediction_horizon 4
# !python evaluate_MAVRIC.py --model models/int_ee --checkpoint=12 --data ./data/processed/Waymo/Waymo_0008_full.pkl --output_path ./data/results/DYNAMICS_INTEGRATION/4sec/VEHICLE/Waymo/0008 --output_tag int_ee --node_type VEHICLE --prediction_horizon 4
# !python evaluate_MAVRIC.py --model models/int_ee --checkpoint=12 --data ./data/processed/Waymo/Waymo_0009_full.pkl --output_path ./data/results/DYNAMICS_INTEGRATION/4sec/VEHICLE/Waymo/0009 --output_tag int_ee --node_type VEHICLE --prediction_horizon 4
# !python evaluate_MAVRIC.py --model models/int_ee --checkpoint=12 --data ./data/processed/Waymo/Waymo_0010_full.pkl --output_path ./data/results/DYNAMICS_INTEGRATION/4sec/VEHICLE/Waymo/0010 --output_tag int_ee --node_type VEHICLE --prediction_horizon 4
# !python evaluate_MAVRIC.py --model models/int_ee --checkpoint=12 --data ./data/processed/Waymo/Waymo_0011_full.pkl --output_path ./data/results/DYNAMICS_INTEGRATION/4sec/VEHICLE/Waymo/0011 --output_tag int_ee --node_type VEHICLE --prediction_horizon 4
# !python evaluate_MAVRIC.py --model models/int_ee --checkpoint=12 --data ./data/processed/Waymo/Waymo_0012_full.pkl --output_path ./data/results/DYNAMICS_INTEGRATION/4sec/VEHICLE/Waymo/0012 --output_tag int_ee --node_type VEHICLE --prediction_horizon 4
# !python evaluate_MAVRIC.py --model models/int_ee --checkpoint=12 --data ./data/processed/Waymo/Waymo_0013_full.pkl --output_path ./data/results/DYNAMICS_INTEGRATION/4sec/VEHICLE/Waymo/0013 --output_tag int_ee --node_type VEHICLE --prediction_horizon 4
# !python evaluate_MAVRIC.py --model models/int_ee --checkpoint=12 --data ./data/processed/Waymo/Waymo_0014_full.pkl --output_path ./data/results/DYNAMICS_INTEGRATION/4sec/VEHICLE/Waymo/0014 --output_tag int_ee --node_type VEHICLE --prediction_horizon 4
# !python evaluate_MAVRIC.py --model models/int_ee --checkpoint=12 --data ./data/processed/Waymo/Waymo_0015_full.pkl --output_path ./data/results/DYNAMICS_INTEGRATION/4sec/VEHICLE/Waymo/0015 --output_tag int_ee --node_type VEHICLE --prediction_horizon 4
# !python evaluate_MAVRIC.py --model models/int_ee --checkpoint=12 --data ./data/processed/Waymo/Waymo_0016_full.pkl --output_path ./data/results/DYNAMICS_INTEGRATION/4sec/VEHICLE/Waymo/0016 --output_tag int_ee --node_type VEHICLE --prediction_horizon 4
# !python evaluate_MAVRIC.py --model models/int_ee --checkpoint=12 --data ./data/processed/Waymo/Waymo_0017_full.pkl --output_path ./data/results/DYNAMICS_INTEGRATION/4sec/VEHICLE/Waymo/0017 --output_tag int_ee --node_type VEHICLE --prediction_horizon 4
# !python evaluate_MAVRIC.py --model models/int_ee --checkpoint=12 --data ./data/processed/Waymo/Waymo_0018_full.pkl --output_path ./data/results/DYNAMICS_INTEGRATION/4sec/VEHICLE/Waymo/0018 --output_tag int_ee --node_type VEHICLE --prediction_horizon 4
# !python evaluate_MAVRIC.py --model models/int_ee --checkpoint=12 --data ./data/processed/Waymo/Waymo_0019_full.pkl --output_path ./data/results/DYNAMICS_INTEGRATION/4sec/VEHICLE/Waymo/0019 --output_tag int_ee --node_type VEHICLE --prediction_horizon 4
# !python evaluate_MAVRIC.py --model models/int_ee --checkpoint=12 --data ./data/processed/Waymo/Waymo_0020_full.pkl --output_path ./data/results/DYNAMICS_INTEGRATION/4sec/VEHICLE/Waymo/0020 --output_tag int_ee --node_type VEHICLE --prediction_horizon 4
# !python evaluate_MAVRIC.py --model models/int_ee --checkpoint=12 --data ./data/processed/Waymo/Waymo_0021_full.pkl --output_path ./data/results/DYNAMICS_INTEGRATION/4sec/VEHICLE/Waymo/0021 --output_tag int_ee --node_type VEHICLE --prediction_horizon 4
# !python evaluate_MAVRIC.py --model models/int_ee --checkpoint=12 --data ./data/processed/Waymo/Waymo_0022_full.pkl --output_path ./data/results/DYNAMICS_INTEGRATION/4sec/VEHICLE/Waymo/0022 --output_tag int_ee --node_type VEHICLE --prediction_horizon 4
# !python evaluate_MAVRIC.py --model models/int_ee --checkpoint=12 --data ./data/processed/Waymo/Waymo_0023_full.pkl --output_path ./data/results/DYNAMICS_INTEGRATION/4sec/VEHICLE/Waymo/0023 --output_tag int_ee --node_type VEHICLE --prediction_horizon 4
# !python evaluate_MAVRIC.py --model models/int_ee --checkpoint=12 --data ./data/processed/Waymo/Waymo_0024_full.pkl --output_path ./data/results/DYNAMICS_INTEGRATION/4sec/VEHICLE/Waymo/0024 --output_tag int_ee --node_type VEHICLE --prediction_horizon 4
# !python evaluate_MAVRIC.py --model models/int_ee --checkpoint=12 --data ./data/processed/Waymo/Waymo_0025_full.pkl --output_path ./data/results/DYNAMICS_INTEGRATION/4sec/VEHICLE/Waymo/0025 --output_tag int_ee --node_type VEHICLE --prediction_horizon 4
# !python evaluate_MAVRIC.py --model models/int_ee --checkpoint=12 --data ./data/processed/Waymo/Waymo_0026_full.pkl --output_path ./data/results/DYNAMICS_INTEGRATION/4sec/VEHICLE/Waymo/0026 --output_tag int_ee --node_type VEHICLE --prediction_horizon 4
# !python evaluate_MAVRIC.py --model models/int_ee --checkpoint=12 --data ./data/processed/Waymo/Waymo_0027_full.pkl --output_path ./data/results/DYNAMICS_INTEGRATION/4sec/VEHICLE/Waymo/0027 --output_tag int_ee --node_type VEHICLE --prediction_horizon 4
# !python evaluate_MAVRIC.py --model models/int_ee --checkpoint=12 --data ./data/processed/Waymo/Waymo_0028_full.pkl --output_path ./data/results/DYNAMICS_INTEGRATION/4sec/VEHICLE/Waymo/0028 --output_tag int_ee --node_type VEHICLE --prediction_horizon 4
# !python evaluate_MAVRIC.py --model models/int_ee --checkpoint=12 --data ./data/processed/Waymo/Waymo_0029_full.pkl --output_path ./data/results/DYNAMICS_INTEGRATION/4sec/VEHICLE/Waymo/0029 --output_tag int_ee --node_type VEHICLE --prediction_horizon 4
# !python evaluate_MAVRIC.py --model models/int_ee --checkpoint=12 --data ./data/processed/Waymo/Waymo_0030_full.pkl --output_path ./data/results/DYNAMICS_INTEGRATION/4sec/VEHICLE/Waymo/0030 --output_tag int_ee --node_type VEHICLE --prediction_horizon 4
# Out:
# Loading from models/int_ee/model_registrar-12.pt
# Loaded!
#
# -- Preparing Node Graph
# 100% 24/24 [00:00<00:00, 35.13it/s]
# Prediction Horizon: 4
# -- Evaluating GMM Z Mode (Most Likely)
# 100% 24/24 [01:04<00:00,  2.69s/it]
# 3.3592253030660517
# -- Evaluating Full
# 100% 24/24 [02:44<00:00,  6.87s/it]
#
# Loading from models/int_ee/model_registrar-12.pt
# Loaded!
#
# -- Preparing Node Graph
# 100% 24/24 [00:08<00:00,  2.92it/s]
# Prediction Horizon: 4
# -- Evaluating GMM Z Mode (Most Likely)
# 100% 24/24 [03:21<00:00,  8.38s/it]
# 0.057433720102535876
# -- Evaluating Full
# 100% 24/24 [07:15<00:00, 18.13s/it]
#
# Loading from models/int_ee/model_registrar-12.pt
# Loaded!
#
# -- Preparing Node Graph
# 100% 25/25 [00:07<00:00,  3.26it/s]
# Prediction Horizon: 4
# -- Evaluating GMM Z Mode (Most Likely)
# 100% 25/25 [02:33<00:00,  6.14s/it]
# 0.1344740208664064
# -- Evaluating Full
# 100% 25/25 [06:29<00:00, 15.58s/it]
#
# Loading from models/int_ee/model_registrar-12.pt
# Loaded!
# ...
