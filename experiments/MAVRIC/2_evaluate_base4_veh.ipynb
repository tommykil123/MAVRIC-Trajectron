# %% [markdown]
# #EVALUATING DATA FOR MULTIPLE DATASETS to fit NuScene format for Trajectron++

# %% [markdown]
# ## Mount the drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## Install necessary requirements for evaluation

# %%
# %cd /content/drive/My Drive/Colab Notebooks/Trajectron++
# !pip install -r requirements.txt

# %% [markdown]
# ## Process the data

# %%
# %cd /content/drive/My Drive/Colab Notebooks/Trajectron++/experiments/MAVRIC
# Out:
# /content/drive/My Drive/Colab Notebooks/Trajectron++/experiments/MAVRIC

# %% [markdown]
# ### NuScenes (Done)
# num_samples = 20

# %%
# !python evaluate_MAVRIC.py --model models/vel_ee --checkpoint=12 --data ./data/processed/nuScenes/nuScenes_01_full.pkl --output_path ./data/results/BASE/4sec/VEHICLE/nuScenes/01 --output_tag vel_ee --node_type VEHICLE --prediction_horizon 4
# !python evaluate_MAVRIC.py --model models/vel_ee --checkpoint=12 --data ./data/processed/nuScenes/nuScenes_02_full.pkl --output_path ./data/results/BASE/4sec/VEHICLE/nuScenes/02 --output_tag vel_ee --node_type VEHICLE --prediction_horizon 4
# !python evaluate_MAVRIC.py --model models/vel_ee --checkpoint=12 --data ./data/processed/nuScenes/nuScenes_03_full.pkl --output_path ./data/results/BASE/4sec/VEHICLE/nuScenes/03 --output_tag vel_ee --node_type VEHICLE --prediction_horizon 4
# !python evaluate_MAVRIC.py --model models/vel_ee --checkpoint=12 --data ./data/processed/nuScenes/nuScenes_04_full.pkl --output_path ./data/results/BASE/4sec/VEHICLE/nuScenes/04 --output_tag vel_ee --node_type VEHICLE --prediction_horizon 4
# !python evaluate_MAVRIC.py --model models/vel_ee --checkpoint=12 --data ./data/processed/nuScenes/nuScenes_05_full.pkl --output_path ./data/results/BASE/4sec/VEHICLE/nuScenes/05 --output_tag vel_ee --node_type VEHICLE --prediction_horizon 4
# !python evaluate_MAVRIC.py --model models/vel_ee --checkpoint=12 --data ./data/processed/nuScenes/nuScenes_06_full.pkl --output_path ./data/results/BASE/4sec/VEHICLE/nuScenes/06 --output_tag vel_ee --node_type VEHICLE --prediction_horizon 4
# !python evaluate_MAVRIC.py --model models/vel_ee --checkpoint=12 --data ./data/processed/nuScenes/nuScenes_07_full.pkl --output_path ./data/results/BASE/4sec/VEHICLE/nuScenes/07 --output_tag vel_ee --node_type VEHICLE --prediction_horizon 4
# !python evaluate_MAVRIC.py --model models/vel_ee --checkpoint=12 --data ./data/processed/nuScenes/nuScenes_08_full.pkl --output_path ./data/results/BASE/4sec/VEHICLE/nuScenes/08 --output_tag vel_ee --node_type VEHICLE --prediction_horizon 4
# !python evaluate_MAVRIC.py --model models/vel_ee --checkpoint=12 --data ./data/processed/nuScenes/nuScenes_09_full.pkl --output_path ./data/results/BASE/4sec/VEHICLE/nuScenes/09 --output_tag vel_ee --node_type VEHICLE --prediction_horizon 4
# !python evaluate_MAVRIC.py --model models/vel_ee --checkpoint=12 --data ./data/processed/nuScenes/nuScenes_10_full.pkl --output_path ./data/results/BASE/4sec/VEHICLE/nuScenes/10 --output_tag vel_ee --node_type VEHICLE --prediction_horizon 4
# Out:
# Loading from models/vel_ee/model_registrar-12.pt
# Loaded!
#
# -- Preparing Node Graph
# 100% 85/85 [00:01<00:00, 56.44it/s]
# Prediction Horizon: 4
# -- Evaluating GMM Z Mode (Most Likely)
# 100% 85/85 [00:29<00:00,  2.91it/s]
# 1.650460302849926
# -- Evaluating Full
# 100% 85/85 [01:12<00:00,  1.18it/s]
#
# Loading from models/vel_ee/model_registrar-12.pt
# Loaded!
#
# -- Preparing Node Graph
# 100% 85/85 [00:02<00:00, 36.25it/s]
# Prediction Horizon: 4
# -- Evaluating GMM Z Mode (Most Likely)
# 100% 85/85 [00:48<00:00,  1.77it/s]
# 1.4529122404577606
# -- Evaluating Full
# 100% 85/85 [01:45<00:00,  1.24s/it]
#
# Loading from models/vel_ee/model_registrar-12.pt
# Loaded!
#
# -- Preparing Node Graph
# 100% 85/85 [00:02<00:00, 35.32it/s]
# Prediction Horizon: 4
# -- Evaluating GMM Z Mode (Most Likely)
# 100% 85/85 [00:34<00:00,  2.48it/s]
# 1.5121784997720016
# -- Evaluating Full
# 100% 85/85 [01:22<00:00,  1.02it/s]
#
# Loading from models/vel_ee/model_registrar-12.pt
# Loaded!
#
# ...

# %% [markdown]
# ### Lyft (Done)

# %%
# !python evaluate_MAVRIC.py --model models/vel_ee --checkpoint=12 --data ./data/processed/Lyft/Lyft_1_full.pkl --output_path ./data/results/BASE/4sec/VEHICLE/Lyft/1 --output_tag vel_ee --node_type VEHICLE --prediction_horizon 4
# !python evaluate_MAVRIC.py --model models/vel_ee --checkpoint=12 --data ./data/processed/Lyft/Lyft_2_full.pkl --output_path ./data/results/BASE/4sec/VEHICLE/Lyft/2 --output_tag vel_ee --node_type VEHICLE --prediction_horizon 4
# Out:
# Loading from models/vel_ee/model_registrar-12.pt
# Loaded!
#
# -- Preparing Node Graph
# 100% 90/90 [00:04<00:00, 21.20it/s]
# Prediction Horizon: 4
# -- Evaluating GMM Z Mode (Most Likely)
# 100% 90/90 [01:34<00:00,  1.05s/it]
# 0.9046037990717108
# -- Evaluating Full
# 100% 90/90 [04:35<00:00,  3.06s/it]
#
# Loading from models/vel_ee/model_registrar-12.pt
# Loaded!
#
# -- Preparing Node Graph
# 100% 90/90 [00:03<00:00, 23.43it/s]
# Prediction Horizon: 4
# -- Evaluating GMM Z Mode (Most Likely)
# 100% 90/90 [01:19<00:00,  1.13it/s]
# 0.9066930102114142
# -- Evaluating Full
# 100% 90/90 [04:03<00:00,  2.71s/it]

# %% [markdown]
# ### Argo (Done)

# %%
# !python evaluate_MAVRIC.py --model models/vel_ee --checkpoint=12 --data ./data/processed/Argoverse/Argoverse_1_full.pkl --output_path ./data/results/BASE/4sec/VEHICLE/Argoverse/1 --output_tag vel_ee --node_type VEHICLE --prediction_horizon 4
# !python evaluate_MAVRIC.py --model models/vel_ee --checkpoint=12 --data ./data/processed/Argoverse/Argoverse_2_full.pkl --output_path ./data/results/BASE/4sec/VEHICLE/Argoverse/2 --output_tag vel_ee --node_type VEHICLE --prediction_horizon 4
# !python evaluate_MAVRIC.py --model models/vel_ee --checkpoint=12 --data ./data/processed/Argoverse/Argoverse_3_full.pkl --output_path ./data/results/BASE/4sec/VEHICLE/Argoverse/3 --output_tag vel_ee --node_type VEHICLE --prediction_horizon 4
# !python evaluate_MAVRIC.py --model models/vel_ee --checkpoint=12 --data ./data/processed/Argoverse/Argoverse_4_full.pkl --output_path ./data/results/BASE/4sec/VEHICLE/Argoverse/4 --output_tag vel_ee --node_type VEHICLE --prediction_horizon 4
# Out:
# Loading from models/vel_ee/model_registrar-12.pt
# Loaded!
#
# -- Preparing Node Graph
# 100% 20/20 [00:00<00:00, 31.27it/s]
# Prediction Horizon: 4
# -- Evaluating GMM Z Mode (Most Likely)
# 100% 20/20 [00:30<00:00,  1.52s/it]
# 0.40005048038618557
# -- Evaluating Full
# 100% 20/20 [01:31<00:00,  4.59s/it]
#
# Loading from models/vel_ee/model_registrar-12.pt
# Loaded!
#
# -- Preparing Node Graph
# 100% 20/20 [00:00<00:00, 31.13it/s]
# Prediction Horizon: 4
# -- Evaluating GMM Z Mode (Most Likely)
# 100% 20/20 [00:28<00:00,  1.40s/it]
# 0.4095056346606023
# -- Evaluating Full
# 100% 20/20 [01:26<00:00,  4.33s/it]
#
# Loading from models/vel_ee/model_registrar-12.pt
# Loaded!
#
# -- Preparing Node Graph
# 100% 20/20 [00:00<00:00, 38.89it/s]
# Prediction Horizon: 4
# -- Evaluating GMM Z Mode (Most Likely)
# 100% 20/20 [00:21<00:00,  1.06s/it]
# 0.43527551646362084
# -- Evaluating Full
# 100% 20/20 [01:08<00:00,  3.44s/it]
#
# Loading from models/vel_ee/model_registrar-12.pt
# Loaded!
# ...

# %% [markdown]
# ### Waymo (Done)

# %%
# !python evaluate_MAVRIC.py --model models/vel_ee --checkpoint=12 --data ./data/processed/Waymo/Waymo_0000_full.pkl --output_path ./data/results/BASE/4sec/VEHICLE/Waymo/0000 --output_tag vel_ee --node_type VEHICLE --prediction_horizon 4
# !python evaluate_MAVRIC.py --model models/vel_ee --checkpoint=12 --data ./data/processed/Waymo/Waymo_0001_full.pkl --output_path ./data/results/BASE/4sec/VEHICLE/Waymo/0001 --output_tag vel_ee --node_type VEHICLE --prediction_horizon 4
# !python evaluate_MAVRIC.py --model models/vel_ee --checkpoint=12 --data ./data/processed/Waymo/Waymo_0002_full.pkl --output_path ./data/results/BASE/4sec/VEHICLE/Waymo/0002 --output_tag vel_ee --node_type VEHICLE --prediction_horizon 4
# !python evaluate_MAVRIC.py --model models/vel_ee --checkpoint=12 --data ./data/processed/Waymo/Waymo_0003_full.pkl --output_path ./data/results/BASE/4sec/VEHICLE/Waymo/0003 --output_tag vel_ee --node_type VEHICLE --prediction_horizon 4
# !python evaluate_MAVRIC.py --model models/vel_ee --checkpoint=12 --data ./data/processed/Waymo/Waymo_0004_full.pkl --output_path ./data/results/BASE/4sec/VEHICLE/Waymo/0004 --output_tag vel_ee --node_type VEHICLE --prediction_horizon 4
# !python evaluate_MAVRIC.py --model models/vel_ee --checkpoint=12 --data ./data/processed/Waymo/Waymo_0005_full.pkl --output_path ./data/results/BASE/4sec/VEHICLE/Waymo/0005 --output_tag vel_ee --node_type VEHICLE --prediction_horizon 4
# !python evaluate_MAVRIC.py --model models/vel_ee --checkpoint=12 --data ./data/processed/Waymo/Waymo_0006_full.pkl --output_path ./data/results/BASE/4sec/VEHICLE/Waymo/0006 --output_tag vel_ee --node_type VEHICLE --prediction_horizon 4
# !python evaluate_MAVRIC.py --model models/vel_ee --checkpoint=12 --data ./data/processed/Waymo/Waymo_0007_full.pkl --output_path ./data/results/BASE/4sec/VEHICLE/Waymo/0007 --output_tag vel_ee --node_type VEHICLE --prediction_horizon 4
# !python evaluate_MAVRIC.py --model models/vel_ee --checkpoint=12 --data ./data/processed/Waymo/Waymo_0008_full.pkl --output_path ./data/results/BASE/4sec/VEHICLE/Waymo/0008 --output_tag vel_ee --node_type VEHICLE --prediction_horizon 4
# !python evaluate_MAVRIC.py --model models/vel_ee --checkpoint=12 --data ./data/processed/Waymo/Waymo_0009_full.pkl --output_path ./data/results/BASE/4sec/VEHICLE/Waymo/0009 --output_tag vel_ee --node_type VEHICLE --prediction_horizon 4
# !python evaluate_MAVRIC.py --model models/vel_ee --checkpoint=12 --data ./data/processed/Waymo/Waymo_0010_full.pkl --output_path ./data/results/BASE/4sec/VEHICLE/Waymo/0010 --output_tag vel_ee --node_type VEHICLE --prediction_horizon 4
# !python evaluate_MAVRIC.py --model models/vel_ee --checkpoint=12 --data ./data/processed/Waymo/Waymo_0011_full.pkl --output_path ./data/results/BASE/4sec/VEHICLE/Waymo/0011 --output_tag vel_ee --node_type VEHICLE --prediction_horizon 4
# !python evaluate_MAVRIC.py --model models/vel_ee --checkpoint=12 --data ./data/processed/Waymo/Waymo_0012_full.pkl --output_path ./data/results/BASE/4sec/VEHICLE/Waymo/0012 --output_tag vel_ee --node_type VEHICLE --prediction_horizon 4
# !python evaluate_MAVRIC.py --model models/vel_ee --checkpoint=12 --data ./data/processed/Waymo/Waymo_0013_full.pkl --output_path ./data/results/BASE/4sec/VEHICLE/Waymo/0013 --output_tag vel_ee --node_type VEHICLE --prediction_horizon 4
# !python evaluate_MAVRIC.py --model models/vel_ee --checkpoint=12 --data ./data/processed/Waymo/Waymo_0014_full.pkl --output_path ./data/results/BASE/4sec/VEHICLE/Waymo/0014 --output_tag vel_ee --node_type VEHICLE --prediction_horizon 4
# !python evaluate_MAVRIC.py --model models/vel_ee --checkpoint=12 --data ./data/processed/Waymo/Waymo_0015_full.pkl --output_path ./data/results/BASE/4sec/VEHICLE/Waymo/0015 --output_tag vel_ee --node_type VEHICLE --prediction_horizon 4
# !python evaluate_MAVRIC.py --model models/vel_ee --checkpoint=12 --data ./data/processed/Waymo/Waymo_0016_full.pkl --output_path ./data/results/BASE/4sec/VEHICLE/Waymo/0016 --output_tag vel_ee --node_type VEHICLE --prediction_horizon 4
# !python evaluate_MAVRIC.py --model models/vel_ee --checkpoint=12 --data ./data/processed/Waymo/Waymo_0017_full.pkl --output_path ./data/results/BASE/4sec/VEHICLE/Waymo/0017 --output_tag vel_ee --node_type VEHICLE --prediction_horizon 4
# !python evaluate_MAVRIC.py --model models/vel_ee --checkpoint=12 --data ./data/processed/Waymo/Waymo_0018_full.pkl --output_path ./data/results/BASE/4sec/VEHICLE/Waymo/0018 --output_tag vel_ee --node_type VEHICLE --prediction_horizon 4
# !python evaluate_MAVRIC.py --model models/vel_ee --checkpoint=12 --data ./data/processed/Waymo/Waymo_0019_full.pkl --output_path ./data/results/BASE/4sec/VEHICLE/Waymo/0019 --output_tag vel_ee --node_type VEHICLE --prediction_horizon 4
# !python evaluate_MAVRIC.py --model models/vel_ee --checkpoint=12 --data ./data/processed/Waymo/Waymo_0020_full.pkl --output_path ./data/results/BASE/4sec/VEHICLE/Waymo/0020 --output_tag vel_ee --node_type VEHICLE --prediction_horizon 4
# !python evaluate_MAVRIC.py --model models/vel_ee --checkpoint=12 --data ./data/processed/Waymo/Waymo_0021_full.pkl --output_path ./data/results/BASE/4sec/VEHICLE/Waymo/0021 --output_tag vel_ee --node_type VEHICLE --prediction_horizon 4
# !python evaluate_MAVRIC.py --model models/vel_ee --checkpoint=12 --data ./data/processed/Waymo/Waymo_0022_full.pkl --output_path ./data/results/BASE/4sec/VEHICLE/Waymo/0022 --output_tag vel_ee --node_type VEHICLE --prediction_horizon 4
# !python evaluate_MAVRIC.py --model models/vel_ee --checkpoint=12 --data ./data/processed/Waymo/Waymo_0023_full.pkl --output_path ./data/results/BASE/4sec/VEHICLE/Waymo/0023 --output_tag vel_ee --node_type VEHICLE --prediction_horizon 4
# !python evaluate_MAVRIC.py --model models/vel_ee --checkpoint=12 --data ./data/processed/Waymo/Waymo_0024_full.pkl --output_path ./data/results/BASE/4sec/VEHICLE/Waymo/0024 --output_tag vel_ee --node_type VEHICLE --prediction_horizon 4
# !python evaluate_MAVRIC.py --model models/vel_ee --checkpoint=12 --data ./data/processed/Waymo/Waymo_0025_full.pkl --output_path ./data/results/BASE/4sec/VEHICLE/Waymo/0025 --output_tag vel_ee --node_type VEHICLE --prediction_horizon 4
# !python evaluate_MAVRIC.py --model models/vel_ee --checkpoint=12 --data ./data/processed/Waymo/Waymo_0026_full.pkl --output_path ./data/results/BASE/4sec/VEHICLE/Waymo/0026 --output_tag vel_ee --node_type VEHICLE --prediction_horizon 4
# !python evaluate_MAVRIC.py --model models/vel_ee --checkpoint=12 --data ./data/processed/Waymo/Waymo_0027_full.pkl --output_path ./data/results/BASE/4sec/VEHICLE/Waymo/0027 --output_tag vel_ee --node_type VEHICLE --prediction_horizon 4
# !python evaluate_MAVRIC.py --model models/vel_ee --checkpoint=12 --data ./data/processed/Waymo/Waymo_0028_full.pkl --output_path ./data/results/BASE/4sec/VEHICLE/Waymo/0028 --output_tag vel_ee --node_type VEHICLE --prediction_horizon 4
# !python evaluate_MAVRIC.py --model models/vel_ee --checkpoint=12 --data ./data/processed/Waymo/Waymo_0029_full.pkl --output_path ./data/results/BASE/4sec/VEHICLE/Waymo/0029 --output_tag vel_ee --node_type VEHICLE --prediction_horizon 4
# !python evaluate_MAVRIC.py --model models/vel_ee --checkpoint=12 --data ./data/processed/Waymo/Waymo_0030_full.pkl --output_path ./data/results/BASE/4sec/VEHICLE/Waymo/0030 --output_tag vel_ee --node_type VEHICLE --prediction_horizon 4
# Out:
# Loading from models/vel_ee/model_registrar-12.pt
# Loaded!
#
# -- Preparing Node Graph
# 100% 24/24 [00:00<00:00, 33.45it/s]
# Prediction Horizon: 4
# -- Evaluating GMM Z Mode (Most Likely)
# 100% 24/24 [01:02<00:00,  2.59s/it]
# 2.9418845162870624
# -- Evaluating Full
# 100% 24/24 [02:37<00:00,  6.54s/it]
#
# Loading from models/vel_ee/model_registrar-12.pt
# Loaded!
#
# -- Preparing Node Graph
# 100% 24/24 [00:08<00:00,  2.94it/s]
# Prediction Horizon: 4
# -- Evaluating GMM Z Mode (Most Likely)
# 100% 24/24 [03:19<00:00,  8.31s/it]
# 0.578343152003804
# -- Evaluating Full
# 100% 24/24 [06:57<00:00, 17.41s/it]
#
# Loading from models/vel_ee/model_registrar-12.pt
# Loaded!
#
# -- Preparing Node Graph
# 100% 25/25 [00:07<00:00,  3.19it/s]
# Prediction Horizon: 4
# -- Evaluating GMM Z Mode (Most Likely)
# 100% 25/25 [02:30<00:00,  6.01s/it]
# 0.8705821172630074
# -- Evaluating Full
# 100% 25/25 [06:10<00:00, 14.83s/it]
#
# Loading from models/vel_ee/model_registrar-12.pt
# Loaded!
#
# ...
