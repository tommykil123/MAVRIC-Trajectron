# %% [markdown]
# #EVALUATING DATA FOR MULTIPLE DATASETS to fit NuScene format for Trajectron++

# %% [markdown]
# ## Mount the drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ## Install necessary requirements for evaluation

# %%
# %cd /content/drive/My Drive/Colab Notebooks/Trajectron++
# !pip install -r requirements.txt

# %% [markdown]
# ## Process the data

# %%
# %cd /content/drive/My Drive/Colab Notebooks/Trajectron++/experiments/MAVRIC
# Out:
# /content/drive/My Drive/Colab Notebooks/Trajectron++/experiments/MAVRIC

# %% [markdown]
# ### NuScenes (Done)
# num_samples = 20

# %%
# !python evaluate_MAVRIC.py --model models/vel_ee --checkpoint=12 --data ./data/processed/nuScenes/nuScenes_01_full.pkl --output_path ./data/results/BASE/6sec/VEHICLE/nuScenes/01 --output_tag vel_ee --node_type VEHICLE --prediction_horizon 6
# !python evaluate_MAVRIC.py --model models/vel_ee --checkpoint=12 --data ./data/processed/nuScenes/nuScenes_02_full.pkl --output_path ./data/results/BASE/6sec/VEHICLE/nuScenes/02 --output_tag vel_ee --node_type VEHICLE --prediction_horizon 6
# !python evaluate_MAVRIC.py --model models/vel_ee --checkpoint=12 --data ./data/processed/nuScenes/nuScenes_03_full.pkl --output_path ./data/results/BASE/6sec/VEHICLE/nuScenes/03 --output_tag vel_ee --node_type VEHICLE --prediction_horizon 6
# !python evaluate_MAVRIC.py --model models/vel_ee --checkpoint=12 --data ./data/processed/nuScenes/nuScenes_04_full.pkl --output_path ./data/results/BASE/6sec/VEHICLE/nuScenes/04 --output_tag vel_ee --node_type VEHICLE --prediction_horizon 6
# !python evaluate_MAVRIC.py --model models/vel_ee --checkpoint=12 --data ./data/processed/nuScenes/nuScenes_05_full.pkl --output_path ./data/results/BASE/6sec/VEHICLE/nuScenes/05 --output_tag vel_ee --node_type VEHICLE --prediction_horizon 6
# !python evaluate_MAVRIC.py --model models/vel_ee --checkpoint=12 --data ./data/processed/nuScenes/nuScenes_06_full.pkl --output_path ./data/results/BASE/6sec/VEHICLE/nuScenes/06 --output_tag vel_ee --node_type VEHICLE --prediction_horizon 6
# !python evaluate_MAVRIC.py --model models/vel_ee --checkpoint=12 --data ./data/processed/nuScenes/nuScenes_07_full.pkl --output_path ./data/results/BASE/6sec/VEHICLE/nuScenes/07 --output_tag vel_ee --node_type VEHICLE --prediction_horizon 6
# !python evaluate_MAVRIC.py --model models/vel_ee --checkpoint=12 --data ./data/processed/nuScenes/nuScenes_08_full.pkl --output_path ./data/results/BASE/6sec/VEHICLE/nuScenes/08 --output_tag vel_ee --node_type VEHICLE --prediction_horizon 6
# !python evaluate_MAVRIC.py --model models/vel_ee --checkpoint=12 --data ./data/processed/nuScenes/nuScenes_09_full.pkl --output_path ./data/results/BASE/6sec/VEHICLE/nuScenes/09 --output_tag vel_ee --node_type VEHICLE --prediction_horizon 6
# !python evaluate_MAVRIC.py --model models/vel_ee --checkpoint=12 --data ./data/processed/nuScenes/nuScenes_10_full.pkl --output_path ./data/results/BASE/6sec/VEHICLE/nuScenes/10 --output_tag vel_ee --node_type VEHICLE --prediction_horizon 6

# %% [markdown]
# ### Lyft (Done)

# %%
# !python evaluate_MAVRIC.py --model models/vel_ee --checkpoint=12 --data ./data/processed/Lyft/Lyft_1_full.pkl --output_path ./data/results/BASE/6sec/VEHICLE/Lyft/1 --output_tag vel_ee --node_type VEHICLE --prediction_horizon 6
# !python evaluate_MAVRIC.py --model models/vel_ee --checkpoint=12 --data ./data/processed/Lyft/Lyft_2_full.pkl --output_path ./data/results/BASE/6sec/VEHICLE/Lyft/2 --output_tag vel_ee --node_type VEHICLE --prediction_horizon 6

# %% [markdown]
# ### Argo (Done)

# %%
# !python evaluate_MAVRIC.py --model models/vel_ee --checkpoint=12 --data ./data/processed/Argoverse/Argoverse_1_full.pkl --output_path ./data/results/BASE/6sec/VEHICLE/Argoverse/1 --output_tag vel_ee --node_type VEHICLE --prediction_horizon 6
# !python evaluate_MAVRIC.py --model models/vel_ee --checkpoint=12 --data ./data/processed/Argoverse/Argoverse_2_full.pkl --output_path ./data/results/BASE/6sec/VEHICLE/Argoverse/2 --output_tag vel_ee --node_type VEHICLE --prediction_horizon 6
# !python evaluate_MAVRIC.py --model models/vel_ee --checkpoint=12 --data ./data/processed/Argoverse/Argoverse_3_full.pkl --output_path ./data/results/BASE/6sec/VEHICLE/Argoverse/3 --output_tag vel_ee --node_type VEHICLE --prediction_horizon 6
# !python evaluate_MAVRIC.py --model models/vel_ee --checkpoint=12 --data ./data/processed/Argoverse/Argoverse_4_full.pkl --output_path ./data/results/BASE/6sec/VEHICLE/Argoverse/4 --output_tag vel_ee --node_type VEHICLE --prediction_horizon 6

# %% [markdown]
# ### Waymo (Done)

# %%
# !python evaluate_MAVRIC.py --model models/vel_ee --checkpoint=12 --data ./data/processed/Waymo/Waymo_0000_full.pkl --output_path ./data/results/BASE/6sec/VEHICLE/Waymo/0000 --output_tag vel_ee --node_type VEHICLE --prediction_horizon 6
# !python evaluate_MAVRIC.py --model models/vel_ee --checkpoint=12 --data ./data/processed/Waymo/Waymo_0001_full.pkl --output_path ./data/results/BASE/6sec/VEHICLE/Waymo/0001 --output_tag vel_ee --node_type VEHICLE --prediction_horizon 6
# !python evaluate_MAVRIC.py --model models/vel_ee --checkpoint=12 --data ./data/processed/Waymo/Waymo_0002_full.pkl --output_path ./data/results/BASE/6sec/VEHICLE/Waymo/0002 --output_tag vel_ee --node_type VEHICLE --prediction_horizon 6
# !python evaluate_MAVRIC.py --model models/vel_ee --checkpoint=12 --data ./data/processed/Waymo/Waymo_0003_full.pkl --output_path ./data/results/BASE/6sec/VEHICLE/Waymo/0003 --output_tag vel_ee --node_type VEHICLE --prediction_horizon 6
# !python evaluate_MAVRIC.py --model models/vel_ee --checkpoint=12 --data ./data/processed/Waymo/Waymo_0004_full.pkl --output_path ./data/results/BASE/6sec/VEHICLE/Waymo/0004 --output_tag vel_ee --node_type VEHICLE --prediction_horizon 6
# !python evaluate_MAVRIC.py --model models/vel_ee --checkpoint=12 --data ./data/processed/Waymo/Waymo_0005_full.pkl --output_path ./data/results/BASE/6sec/VEHICLE/Waymo/0005 --output_tag vel_ee --node_type VEHICLE --prediction_horizon 6
# !python evaluate_MAVRIC.py --model models/vel_ee --checkpoint=12 --data ./data/processed/Waymo/Waymo_0006_full.pkl --output_path ./data/results/BASE/6sec/VEHICLE/Waymo/0006 --output_tag vel_ee --node_type VEHICLE --prediction_horizon 6
# !python evaluate_MAVRIC.py --model models/vel_ee --checkpoint=12 --data ./data/processed/Waymo/Waymo_0007_full.pkl --output_path ./data/results/BASE/6sec/VEHICLE/Waymo/0007 --output_tag vel_ee --node_type VEHICLE --prediction_horizon 6
# !python evaluate_MAVRIC.py --model models/vel_ee --checkpoint=12 --data ./data/processed/Waymo/Waymo_0008_full.pkl --output_path ./data/results/BASE/6sec/VEHICLE/Waymo/0008 --output_tag vel_ee --node_type VEHICLE --prediction_horizon 6
# !python evaluate_MAVRIC.py --model models/vel_ee --checkpoint=12 --data ./data/processed/Waymo/Waymo_0009_full.pkl --output_path ./data/results/BASE/6sec/VEHICLE/Waymo/0009 --output_tag vel_ee --node_type VEHICLE --prediction_horizon 6
# !python evaluate_MAVRIC.py --model models/vel_ee --checkpoint=12 --data ./data/processed/Waymo/Waymo_0010_full.pkl --output_path ./data/results/BASE/6sec/VEHICLE/Waymo/0010 --output_tag vel_ee --node_type VEHICLE --prediction_horizon 6
# !python evaluate_MAVRIC.py --model models/vel_ee --checkpoint=12 --data ./data/processed/Waymo/Waymo_0011_full.pkl --output_path ./data/results/BASE/6sec/VEHICLE/Waymo/0011 --output_tag vel_ee --node_type VEHICLE --prediction_horizon 6
# !python evaluate_MAVRIC.py --model models/vel_ee --checkpoint=12 --data ./data/processed/Waymo/Waymo_0012_full.pkl --output_path ./data/results/BASE/6sec/VEHICLE/Waymo/0012 --output_tag vel_ee --node_type VEHICLE --prediction_horizon 6
# !python evaluate_MAVRIC.py --model models/vel_ee --checkpoint=12 --data ./data/processed/Waymo/Waymo_0013_full.pkl --output_path ./data/results/BASE/6sec/VEHICLE/Waymo/0013 --output_tag vel_ee --node_type VEHICLE --prediction_horizon 6
# !python evaluate_MAVRIC.py --model models/vel_ee --checkpoint=12 --data ./data/processed/Waymo/Waymo_0014_full.pkl --output_path ./data/results/BASE/6sec/VEHICLE/Waymo/0014 --output_tag vel_ee --node_type VEHICLE --prediction_horizon 6
# !python evaluate_MAVRIC.py --model models/vel_ee --checkpoint=12 --data ./data/processed/Waymo/Waymo_0015_full.pkl --output_path ./data/results/BASE/6sec/VEHICLE/Waymo/0015 --output_tag vel_ee --node_type VEHICLE --prediction_horizon 6
# !python evaluate_MAVRIC.py --model models/vel_ee --checkpoint=12 --data ./data/processed/Waymo/Waymo_0016_full.pkl --output_path ./data/results/BASE/6sec/VEHICLE/Waymo/0016 --output_tag vel_ee --node_type VEHICLE --prediction_horizon 6
# !python evaluate_MAVRIC.py --model models/vel_ee --checkpoint=12 --data ./data/processed/Waymo/Waymo_0017_full.pkl --output_path ./data/results/BASE/6sec/VEHICLE/Waymo/0017 --output_tag vel_ee --node_type VEHICLE --prediction_horizon 6
# !python evaluate_MAVRIC.py --model models/vel_ee --checkpoint=12 --data ./data/processed/Waymo/Waymo_0018_full.pkl --output_path ./data/results/BASE/6sec/VEHICLE/Waymo/0018 --output_tag vel_ee --node_type VEHICLE --prediction_horizon 6
# !python evaluate_MAVRIC.py --model models/vel_ee --checkpoint=12 --data ./data/processed/Waymo/Waymo_0019_full.pkl --output_path ./data/results/BASE/6sec/VEHICLE/Waymo/0019 --output_tag vel_ee --node_type VEHICLE --prediction_horizon 6
# !python evaluate_MAVRIC.py --model models/vel_ee --checkpoint=12 --data ./data/processed/Waymo/Waymo_0020_full.pkl --output_path ./data/results/BASE/6sec/VEHICLE/Waymo/0020 --output_tag vel_ee --node_type VEHICLE --prediction_horizon 6
# !python evaluate_MAVRIC.py --model models/vel_ee --checkpoint=12 --data ./data/processed/Waymo/Waymo_0021_full.pkl --output_path ./data/results/BASE/6sec/VEHICLE/Waymo/0021 --output_tag vel_ee --node_type VEHICLE --prediction_horizon 6
# !python evaluate_MAVRIC.py --model models/vel_ee --checkpoint=12 --data ./data/processed/Waymo/Waymo_0022_full.pkl --output_path ./data/results/BASE/6sec/VEHICLE/Waymo/0022 --output_tag vel_ee --node_type VEHICLE --prediction_horizon 6
# !python evaluate_MAVRIC.py --model models/vel_ee --checkpoint=12 --data ./data/processed/Waymo/Waymo_0023_full.pkl --output_path ./data/results/BASE/6sec/VEHICLE/Waymo/0023 --output_tag vel_ee --node_type VEHICLE --prediction_horizon 6
# !python evaluate_MAVRIC.py --model models/vel_ee --checkpoint=12 --data ./data/processed/Waymo/Waymo_0024_full.pkl --output_path ./data/results/BASE/6sec/VEHICLE/Waymo/0024 --output_tag vel_ee --node_type VEHICLE --prediction_horizon 6
# !python evaluate_MAVRIC.py --model models/vel_ee --checkpoint=12 --data ./data/processed/Waymo/Waymo_0025_full.pkl --output_path ./data/results/BASE/6sec/VEHICLE/Waymo/0025 --output_tag vel_ee --node_type VEHICLE --prediction_horizon 6
# !python evaluate_MAVRIC.py --model models/vel_ee --checkpoint=12 --data ./data/processed/Waymo/Waymo_0026_full.pkl --output_path ./data/results/BASE/6sec/VEHICLE/Waymo/0026 --output_tag vel_ee --node_type VEHICLE --prediction_horizon 6
# !python evaluate_MAVRIC.py --model models/vel_ee --checkpoint=12 --data ./data/processed/Waymo/Waymo_0027_full.pkl --output_path ./data/results/BASE/6sec/VEHICLE/Waymo/0027 --output_tag vel_ee --node_type VEHICLE --prediction_horizon 6
# !python evaluate_MAVRIC.py --model models/vel_ee --checkpoint=12 --data ./data/processed/Waymo/Waymo_0028_full.pkl --output_path ./data/results/BASE/6sec/VEHICLE/Waymo/0028 --output_tag vel_ee --node_type VEHICLE --prediction_horizon 6
# !python evaluate_MAVRIC.py --model models/vel_ee --checkpoint=12 --data ./data/processed/Waymo/Waymo_0029_full.pkl --output_path ./data/results/BASE/6sec/VEHICLE/Waymo/0029 --output_tag vel_ee --node_type VEHICLE --prediction_horizon 6
# !python evaluate_MAVRIC.py --model models/vel_ee --checkpoint=12 --data ./data/processed/Waymo/Waymo_0030_full.pkl --output_path ./data/results/BASE/6sec/VEHICLE/Waymo/0030 --output_tag vel_ee --node_type VEHICLE --prediction_horizon 6
