# %% [markdown]
# #PROCESSING DATA FOR MULTIPLE DATASETS to fit NuScene format for Trajectron++

# %% [markdown]
# ## Mount the drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ## Install necessary requirements for evaluation

# %%
# %cd /content/drive/My Drive/Colab Notebooks/Trajectron++
# !pip install -r requirements.txt

# %% [markdown]
# ## Process the data

# %%
# %cd /content/drive/My Drive/Colab Notebooks/Trajectron++/experiments/MAVRIC
# Out:
# /content/drive/My Drive/Colab Notebooks/Trajectron++/experiments/MAVRIC

# %% [markdown]
# ### NuScenes (Done!)

# %%
# !python process_data_MAVRIC.py --data=./data/data/nuScenes/01 --output_path=./data/processed/nuScenes
# !python process_data_MAVRIC.py --data=./data/data/nuScenes/02 --output_path=./data/processed/nuScenes
# !python process_data_MAVRIC.py --data=./data/data/nuScenes/03 --output_path=./data/processed/nuScenes
# !python process_data_MAVRIC.py --data=./data/data/nuScenes/04 --output_path=./data/processed/nuScenes
# !python process_data_MAVRIC.py --data=./data/data/nuScenes/05 --output_path=./data/processed/nuScenes
# !python process_data_MAVRIC.py --data=./data/data/nuScenes/06 --output_path=./data/processed/nuScenes
# !python process_data_MAVRIC.py --data=./data/data/nuScenes/07 --output_path=./data/processed/nuScenes
# !python process_data_MAVRIC.py --data=./data/data/nuScenes/08 --output_path=./data/processed/nuScenes
# !python process_data_MAVRIC.py --data=./data/data/nuScenes/09 --output_path=./data/processed/nuScenes
# !python process_data_MAVRIC.py --data=./data/data/nuScenes/10 --output_path=./data/processed/nuScenes

# %% [markdown]
# ### Lyft (Done!)

# %%
# !python process_data_MAVRIC.py --data=./data/data/Lyft/1 --output_path=./data/processed/Lyft
# !python process_data_MAVRIC.py --data=./data/data/Lyft/2 --output_path=./data/processed/Lyft

# %% [markdown]
# ### Argo (Done!)

# %%
# !python process_data_MAVRIC.py --data=./data/data/Argoverse/1 --output_path=./data/processed/Argoverse
# !python process_data_MAVRIC.py --data=./data/data/Argoverse/2 --output_path=./data/processed/Argoverse
# !python process_data_MAVRIC.py --data=./data/data/Argoverse/3 --output_path=./data/processed/Argoverse
# !python process_data_MAVRIC.py --data=./data/data/Argoverse/4 --output_path=./data/processed/Argoverse

# %% [markdown]
# ### Waymo (done!)

# %%
# !python process_data_MAVRIC.py --data=./data/data/Waymo/0000 --output_path=./data/processed/Waymo
# !python process_data_MAVRIC.py --data=./data/data/Waymo/0001 --output_path=./data/processed/Waymo
# !python process_data_MAVRIC.py --data=./data/data/Waymo/0002 --output_path=./data/processed/Waymo
# !python process_data_MAVRIC.py --data=./data/data/Waymo/0003 --output_path=./data/processed/Waymo
# !python process_data_MAVRIC.py --data=./data/data/Waymo/0004 --output_path=./data/processed/Waymo
# !python process_data_MAVRIC.py --data=./data/data/Waymo/0005 --output_path=./data/processed/Waymo
# !python process_data_MAVRIC.py --data=./data/data/Waymo/0006 --output_path=./data/processed/Waymo
# !python process_data_MAVRIC.py --data=./data/data/Waymo/0007 --output_path=./data/processed/Waymo
# !python process_data_MAVRIC.py --data=./data/data/Waymo/0008 --output_path=./data/processed/Waymo
# !python process_data_MAVRIC.py --data=./data/data/Waymo/0009 --output_path=./data/processed/Waymo
# !python process_data_MAVRIC.py --data=./data/data/Waymo/0010 --output_path=./data/processed/Waymo
# !python process_data_MAVRIC.py --data=./data/data/Waymo/0011 --output_path=./data/processed/Waymo
# !python process_data_MAVRIC.py --data=./data/data/Waymo/0012 --output_path=./data/processed/Waymo
# !python process_data_MAVRIC.py --data=./data/data/Waymo/0013 --output_path=./data/processed/Waymo
# !python process_data_MAVRIC.py --data=./data/data/Waymo/0014 --output_path=./data/processed/Waymo
# !python process_data_MAVRIC.py --data=./data/data/Waymo/0015 --output_path=./data/processed/Waymo
# !python process_data_MAVRIC.py --data=./data/data/Waymo/0016 --output_path=./data/processed/Waymo
# !python process_data_MAVRIC.py --data=./data/data/Waymo/0017 --output_path=./data/processed/Waymo
# !python process_data_MAVRIC.py --data=./data/data/Waymo/0018 --output_path=./data/processed/Waymo
# !python process_data_MAVRIC.py --data=./data/data/Waymo/0019 --output_path=./data/processed/Waymo
# !python process_data_MAVRIC.py --data=./data/data/Waymo/0020 --output_path=./data/processed/Waymo
# !python process_data_MAVRIC.py --data=./data/data/Waymo/0021 --output_path=./data/processed/Waymo
# !python process_data_MAVRIC.py --data=./data/data/Waymo/0022 --output_path=./data/processed/Waymo
# !python process_data_MAVRIC.py --data=./data/data/Waymo/0023 --output_path=./data/processed/Waymo
# !python process_data_MAVRIC.py --data=./data/data/Waymo/0024 --output_path=./data/processed/Waymo
# !python process_data_MAVRIC.py --data=./data/data/Waymo/0025 --output_path=./data/processed/Waymo
# !python process_data_MAVRIC.py --data=./data/data/Waymo/0026 --output_path=./data/processed/Waymo
# !python process_data_MAVRIC.py --data=./data/data/Waymo/0027 --output_path=./data/processed/Waymo
# !python process_data_MAVRIC.py --data=./data/data/Waymo/0028 --output_path=./data/processed/Waymo
# !python process_data_MAVRIC.py --data=./data/data/Waymo/0029 --output_path=./data/processed/Waymo
# !python process_data_MAVRIC.py --data=./data/data/Waymo/0030 --output_path=./data/processed/Waymo
# !python process_data_MAVRIC.py --data=./data/data/Waymo/0031 --output_path=./data/processed/Waymo
