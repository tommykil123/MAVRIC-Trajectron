# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ## Run this to create the .pkl for deriving scenes

# %%
# !python process_data.py --data=./v1.0-mini --version="v1.0-mini" --output_path=../processed
# !python process_data.py --data=./v1.0 --version="v1.0-trainval" --output_path=../processe
# Out:
# ======
# Loading NuScenes tables for version v1.0-trainval...

# %%
# %cd /content/drive/My Drive/Colab Notebooks/Trajectron++
# !pip install -r requirements.txt

# %%
# %cd /content/drive/My Drive/Colab Notebooks/Trajectron++/experiments/nuScenes
# Out:
# /content/drive/My Drive/Colab Notebooks/Trajectron++/experiments/nuScenes

# %%
# %matplotlib inline
import sys
sys.path.append('../../trajectron')
import os
import numpy as np
import torch
import dill
import json
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import matplotlib.patheffects as pe
from helper import *
import visualization

# %%
# !python evaluate.py --model models/vel_ee --checkpoint=12 --data ../processed/MAVRIC_nuScenes_01train_mini_full.pkl --output_path results/MAVRIC/nuScenes/01 --output_tag vel_ee --node_type VEHICLE --prediction_horizon 6
# Out:
# python3: can't open file 'evaluate.py': [Errno 2] No such file or directory

# %%
# !python evaluate.py --model models/vel_ee --checkpoint=12 --data ../processed/MAVRIC_Argo_1train_mini_full.pkl --output_path results/MAVRIC/Argo/1 --output_tag vel_ee --node_type VEHICLE --prediction_horizon 6
# Out:
# Loading from models/vel_ee/model_registrar-12.pt
# Loaded!
#
# -- Preparing Node Graph
# 100% 15/15 [00:00<00:00, 32.57it/s]
# Prediction Horizon: 6
# -- Evaluating GMM Z Mode (Most Likely)
# 100% 15/15 [00:23<00:00,  1.54s/it]
# 0.6974651453433902
# -- Evaluating Full
#   0% 0/15 [00:00<?, ?it/s]tcmalloc: large alloc 1206788096 bytes == 0x2cb54000 @  0x7f15452e1b6b 0x7f1545301379 0x7f14eaa1fb4a 0x7f14eaa215fa 0x7f14ecd5178a 0x7f14ecf9a30b 0x7f14ecfe1b37 0x7f14ecd8a880 0x7f14ecd9d0e1 0x7f14ed0b6542 0x7f14ecfe20e3 0x7f14eca11dd8 0x7f14eed221ff 0x7f14ecfe20e3 0x7f153588eded 0x7f15357931d8 0x50a7f5 0x50c1f4 0x507f24 0x509c50 0x50a64d 0x50c1f4 0x507f24 0x509c50 0x50a64d 0x50cfd6 0x507f24 0x509c50 0x50a64d 0x50cfd6 0x507f24
# tcmalloc: large alloc 1678188544 bytes == 0x74a36000 @  0x7f15452e1b6b 0x7f1545301379 0x7f14eaa1fb4a 0x7f14eaa215fa 0x7f14ed1279fb 0x7f14ed13b5cd 0x7f14ed147bf7 0x7f14ed02d2f0 0x7f14ecfe14c5 0x7f14ecfe2aa9 0x7f14ecd99c3e 0x7f14ed0a0f0a 0x7f14ecfe2aa9 0x7f14eedf8174 0x7f14ecfe2aa9 0x7f1535ace6b0 0x7f1535a31b25 0x50a7f5 0x50cfd6 0x507f24 0x509c50 0x50a64d 0x50c1f4 0x507f24 0x509c50 0x50a64d 0x50cfd6 0x507f24 0x509c50 0x50a64d 0x50cfd6
# tcmalloc: large alloc 2413568000 bytes == 0xd8aa8000 @  0x7f15452e1b6b 0x7f1545301379 0x7f14eaa1fb4a 0x7f14eaa215fa 0x7f14ed1279fb 0x7f14ed13b5cd 0x7f14ed19adf8 0x7f14ed19b63f 0x7f14ed03f7e2 0x7f14ed070ba6 0x7f14ecfdfe0b 0x7f14ecfe180e 0x7f14eec188fd 0x7f14ecfe180e 0x7f15358a7671 0x7f15358a90db 0x7f1535a5fe33 0x50a7f5 0x50c1f4 0x507f24 0x509c50 0x50a64d 0x
0x7f6647aacb1b 0x7f6647eece9f 0x7f664993e3ea 0x7f6647f04973 0x7f66908fb513 0x7f66907ed87e 0x50a7f5 0x50c1f4 0x507f24 0x509202 0x594b01
#  33% 5/15 [04:45<09:38, 57.88s/it]tcmalloc: large alloc 13667328000 bytes == 0x7f5dfc6ea000 @  0x7f66a010bb6b 0x7f66a012b379 0x7f6645849b4a 0x7f664584b5fa 0x7f6647f519fb 0x7f6647f655cd 0x7f6647fc4df8 0x7f6647fc563f 0x7f6647e697e2 0x7f6647e9aba6 0x7f6647e09e0b 0x7f6647e0b80e 0x7f6649a428fd 0x7f6647e0b80e 0x7f66479afb40 0x7f6647ed4c79 0x7f664993e9bd 0x7f6647e0c213 0x7f6647aa82cd 0x7f6647aac3bb 0x7f6647aacb1b 0x7f6647eece9f 0x7f664993e3ea 0x7f6647f04973 0x7f66908fb513 0x7f66907ed87e 0x50a7f5 0x50c1f4 0x507f24 0x509202 0x594b01
# ^C

# %%
# !python evaluate.py --model models/vel_ee --checkpoint=12 --data ../processed/MAVRIC_Lyft_1train_mini_full.pkl --output_path results/MAVRIC/Lyft/1 --output_tag vel_ee --node_type VEHICLE --prediction_horizon 6
# Out:
# Loading from models/vel_ee/model_registrar-12.pt
# Loaded!
#
# -- Preparing Node Graph
# 100% 71/71 [00:03<00:00, 19.14it/s]
# Prediction Horizon: 6
# -- Evaluating GMM Z Mode (Most Likely)
# 100% 71/71 [01:06<00:00,  1.07it/s]
# 1.1310845794689441
# -- Evaluating Full
#   0% 0/71 [00:00<?, ?it/s]tcmalloc: large alloc 2580480000 bytes == 0xcceb6000 @  0x7f83b4347b6b 0x7f83b4367379 0x7f8359a85b4a 0x7f8359a875fa 0x7f835c18d9fb 0x7f835c1a15cd 0x7f835c200df8 0x7f835c20163f 0x7f835c0a57e2 0x7f835c0d6ba6 0x7f835c045e0b 0x7f835c04780e 0x7f835dc7e8fd 0x7f835c04780e 0x7f835bbebb40 0x7f835c110c79 0x7f835db7a9bd 0x7f835c048213 0x7f835bce42cd 0x7f835bce83bb 0x7f835bce8b1b 0x7f835c128e9f 0x7f835db7a3ea 0x7f835c140973 0x7f83a4b37513 0x7f83a4a2987e 0x50a7f5 0x50c1f4 0x507f24 0x509202 0x594b01
# tcmalloc: large alloc 2580480000 bytes == 0x7f8281b10000 @  0x7f83b4347b6b 0x7f83b4367379 0x7f8359a85b4a 0x7f8359a875fa 0x7f835c18d9fb 0x7f835c1a15cd 0x7f835c200df8 0x7f835c20163f 0x7f835c0a57e2 0x7f835c0d6ba6 0x7f835c045e0b 0x7f835c04780e 0x7f835dc7e8fd 0x7f835c04780e 0x7f835bbebb40 0x7f835c110c79 0x7f835db7a9bd 0x7f835c048213 0x7f835bce42cd 0x7f835bce817d 0x7f835bce8b1b 0x7f835c128e9f 0x7f835db7a3ea 0x7f835c140973 0x7f83a4b37513 0x7f83a4a2987e 0x50a7f5 0x50c1f4 0x507f24 0x509202 0x594b01
# tcmalloc: large alloc 2580480000 bytes == 0x7f8281b10000 @  0x7f83b4347b6b 0x7f83b4367379 0x7f8359a85b4a 0x7f8359a875fa 0x7f835c18d9fb 0x7f835c1a15cd 0x7f835c200df8 0x7f835c20163f 0x7f835c0a57e2 0x7f835c0d6ba6 0x7f835c045e0b 0x7f835c04780e 0x7f835dc7e8fd 0x7f835c04780e 0x7f835bbebb40 0x7f835c110c79 0x7f835db7a9bd 0x7f835c048213 0x7f835bce42cd 0x7f835bce83bb 0x7f835bce8b1b 0x7f835c128e9f 0x7f835db7a3ea 0x7f835c140973 0x7f83a4b37513 0x7f83a4a2987e 0x50a7f5 0x50c1f4 0x507f24 0x509202 0x594b01
# tcmalloc: large alloc 2580480000 bytes == 0xa811c000 @  0x7f83b4347b6b 0x7f83b4367379 0x7f8359a85b4a 0x7f8359a875fa 0x7f835c18d9fb 0x7f835c1a15cd 0x7f835c200df8 0x7f835c20163f 0x7f835c0a57e2 0x7f835c0d6ba6 0x7f835c045e0b 0x7f835c04780e 0x7f835dc7e8fd 0x7f835c04780e 0x7f835bbebb40 0x7f835c110c79 0x7f835db7a9bd 0x7f835c048213 0x7f835bce42cd 0x7f835bce817d 0x7f835bce8b1b 0x7f835c128e9f 0x7f835db7a3ea 0x7f835c140973 0x7f83a4b37513 0x7f83a4a2987e 0x50a7f5 0x50c1f4 0x507f24 0x509202 0x594b01
# tcmalloc: large alloc 2580480000 bytes == 0xa7ab2000 @  0x7f83b4347b6b 0x7f83b4367379 0x7f8359a85b4a 0x7f8359a875fa 0x7f835c18d9fb 0x7f835c1a15cd 0x7f835c200df8 0x7f835c20163f 0x7f835c0a57e2 0x7f835c0d6ba6 0x7f835c045e0b 0x7f835c04780e 0x7f835dc7e8fd 0x7f835c04780e 0x7f835bbebb40 0x7f835c110c79 0x7f835db7a9bd 0x7f835c048213 0x7f835bce42cd 0x7f835bce83bb 0x7f835bce8b1b 0x7f835c128e9f 0x7f835db7a3ea 0x7f835c140973 0x7f83a4b37513 0x7f83a4a2987e 0x50a7f5 0x50c1f4 0x507f24 0x509202 0x594b01
# tcmalloc: large alloc 2580480000 bytes == 0x7f814d930000 @  0x7f83b4347b6b 0x7f83b4367379 0x7f8359a85b4a 0x7f8359a875fa 0x7f835c18d9fb 0x7f835c1a15cd 0x7f835c200df8 0x7f835c20163f 0x7f835c0a57e2 0x7f835c0d6ba6 0x7f835c045e0b 0x7f835c04780e 0x7f835dc7e8fd 0x7f835c04780e 0x7f835bbebb40 0x7f835c110c79 0x7f835db7a9bd 0x7f835c048213 0x7f835bce42cd 0x7f835bce817d 0x7f835bce8b1b 0x7f835c128e9f 0x7f835db7a3ea 0x7f835c140973 0x7f83a4b37513 0x7f83a4a2987e 0x50a7f5 0x50c1f4 0x507f24 0x509202 0x594b01
# tcmalloc: large alloc 2580480000 bytes == 0x7f8281b10000 @  0x7f83b4347b6b 0x7f83b4367379 0x7f8359a85b4a 0x7f8359a875fa 0x7f835c18d9fb 0x7f835c1a15cd 0x7f835c200df8 0x7f835c20163f 0x7f835c0a57e2 0x7f835c0d6ba6 0x7f835c045e0b 0x7f835c04780e 0x7f835dc7e8fd 0x7f835c04780e 0x7f835bbebb40 0x7f835c110c79 0x7f835db7a9bd 0x7f835c048213 0x7f835bce42cd 0x7f835bce83bb 0x7f835bce8b1b 0x7f835c128e9f 0x7f835db7a3ea 0x7f835c140973 0x7f83a4b37513 0x7f83a4a2987e 0x50a7f5 0x50c1f4 0x507f24 0x509202 0x594b01
# tcmalloc: large alloc 2580480000 bytes == 0x7f814d930000 @  0x7f83b4347b6b 0x7f83b4367379 0x7f8359a85b4a 0x7f8359a875fa 0x7f835c18d9fb 0x7f835c1a15cd 0x7f835c200df8 0x7f835c20163f 0x7f835c0a57e2 0x7f835c0d6ba6 0x7f835c045e0b 0x7f835c04780e 0x7f835dc7e8fd 0x7f835c04780e 0x7f835bbebb40 0x7f835c110c79 0x7f835db7a9bd 0x7f835c048213 0x7f835bce42cd 0x7f835bce817d 0x7f835bce8b1b 0x7f835c128e9f 0x7f835db7a3ea 0x7f835c140973 0x7f83a4b37513 0x7f83a4a2987e 0x50a7f5 0x50c1f4 0x507f24 0x509202 0x594b01
#   1% 1/71 [00:43<50:14, 43.06s/it]tcmalloc: large alloc 4936704000 bytes == 0x2d16a000 @  0x7f83b4347b6b 0x7f83b4367379 0x7f8359a85b4a 0x7f8359a875fa 0x7f835c18d9fb 0x7f835c1a15cd 0x7f835c200df8 0x7f835c20163f 0x7f835c0a57e2 0x7f835c0d6ba6 0x7f835c045e0b 0x7f835c04780e 0x7f835dc7e8fd 0x7f835c04780e 0x7f835bbebb40 0x7f835c110c79 0x7f835db7a9bd 0x7f835c048213 0x7f835bce42cd 0x7f835bce83bb 0x7f835bce8b1b 0x7f835c128e9f 0x7f835db7a3ea 0x7f835c140973 0x7f83a4b37513 0x7f83a4a2987e 0x50a7f5 0x50c1f4 0x507f24 0x509202 0x594b01
# tcmalloc: large alloc 4936704000 bytes == 0x7f8022cae000 @  0x7f83b4347b6b 0x7f83b4367379 0x7f8359a85b4a 0x7f8359a875fa 0x7f835c18d9fb 0x7f835c1a15cd 0x7f835c200df8 0x7f835c20163f 0x7f835c0a57e2 0x7f835c0d6ba6 0x7f835c045e0b 0x7f835c04780e 0x7f835dc7e8fd 0x7f835c04780e 0x7f835bbebb40 0x7f835c110c79 0x7f835db7a9bd 0x7f835c048213 0x7f835bce42cd 0x7f835bce817d 0x7f835bce8b1b 0x7f835c128e9f 0x7f835db7a3ea 0x7f835c140973 0x7f83a4b37513 0x7f83a4a2987e 0x50a7f5 0x50c1f4 0x507f24 0x509202 0x594b01
# tcmalloc: large alloc 4936704000 bytes == 0x7f8022cae000 @  0x7f83b4347b6b 0x7f83b4367379 0x7f8359a85b4a 0x7f8359a875fa 0x7f835c18d9fb 0x7f835c1a15cd 0x7f835c200df8 0x7f835c20163f 0x7f835c0a57e2 0x7f835c0d6ba6 0x7f835c045e0b 0x7f835c04780e 0x7f835dc7e8fd 0x7f835c04780e 0x7f835bbebb40 0x7f835c110c79 0x7f835db7a9bd 0x7f835c048213 0x7f835bce42cd 0x7f835bce83bb 0x7f835bce8b1b 0x7f835c128e9f 0x7f835db7a3ea 0x7f835c140973 0x7f83a4b37513 0x7f83a4a2987e 0x50a7f5 0x50c1f4 0x507f24 0x509202 0x594b01
# tcmalloc: large alloc 4936704000 bytes == 0x2d16a000 @  0x7f83b4347b6b 0x7f83b4367379 0x7f8359a85b4a 0x7f8359a875fa 0x7f835c18d9fb 0x7f835c1a15cd 0x7f835c200df8 0x7f835c20163f 0x7f835c0a57e2 0x7f835c0d6ba6 0x7f835c045e0b 0x7f835c04780e 0x7f835dc7e8fd 0x7f835c04780e 0x7f835bbebb40 0x7f835c110c79 0x7f835db7a9bd 0x7f835c048213 0x7f835bce42cd 0x7f835bce817d 0x7f835bce8b1b 0x7f835c128e9f 0x7f835db7a3ea 0x7f835c140973 0x7f83a4b37513 0x7f83a4a2987e 0x50a7f5 0x50c1f4 0x507f24 0x509202 0x594b01
# tcmalloc: large alloc 4936704000 bytes == 0x7f8022cae000 @  0x7f83b4347b6b 0x7f83b4367379 0x7f8359a85b4a 0x7f8359a875fa 0x7f835c18d9fb 0x7f835c1a15cd 0x7f835c200df8 0x7f835c20163f 0x7f835c0a57e2 0x7f835c0d6ba6 0x7f835c045e0b 0x7f835c04780e 0x7f835dc7e8fd 0x7f835c04780e 0x7f835bbebb40 0x7f835c110c79 0x7f835db7a9bd 0x7f835c048213 0x7f835bce42cd 0x7f835bce83bb 0x7f835bce8b1b 0x7f835c128e9f 0x7f835db7a3ea 0x7f835c140973 0x7f83a4b37513 0x7f83a4a2987e 0x50a7f5 0x50c1f4 0x507f24 0x509202 0x594b01
#   7% 5/71 [04:07<46:27, 42.24s/it]  tcmalloc: large alloc 8534016000 bytes == 0x7f7c9186a000 @  0x7f83b4347b6b 0x7f83b4367379 0x7f8359a85b4a 0x7f8359a875fa 0x7f835c18d9fb 0x7f835c1a15cd 0x7f835c200df8 0x7f835c20163f 0x7f835c0a57e2 0x7f835c0d6ba6 0x7f835c045e0b 0x7f835c04780e 0x7f835dc7e8fd 0x7f835c04780e 0x7f835bbebb40 0x7f835c110c79 0x7f835db7a9bd 0x7f835c048213 0x7f835bce42cd 0x7f835bce83bb 0x7f835bce8b1b 0x7f835c128e9f 0x7f835db7a3ea 0x7f835c140973 0x7f83a4b37513 0x7f83a4a2987e 0x50a7f5 0x50c1f4 0x507f24 0x509202 0x594b01
# tcmalloc: large alloc 8534016000 bytes == 0x7f7a94dbe000 @  0x7f83b4347b6b 0x7f83b4367379 0x7f8359a85b4a 0x7f8359a875fa 0x7f835c18d9fb 0x7f835c1a15cd 0x7f835c200df8 0x7f835c20163f 0x7f835c0a57e2 0x7f835c0d6ba6 0x7f835c045e0b 0x7f835c04780e 0x7f835dc7e8fd 0x7f835c04780e 0x7f835bbebb40 0x7f835c110c79 0x7f835db7a9bd 0x7f835c048213 0x7f835bce42cd 0x7f835bce817d 0x7f835bce8b1b 0x7f835c128e9f 0x7f835db7a3ea 0x7f835c140973 0x7f83a4b37513 0x7f83a4a2987e 0x50a7f5 0x50c1f4 0x507f24 0x509202 0x594b01
# ^C

# %%
# !python evaluate.py --model models/vel_ee --checkpoint=12 --data ../processed/MAVRIC_Lyft_2train_mini_full.pkl --output_path results/MAVRIC/Lyft/2 --output_tag vel_ee --node_type VEHICLE --prediction_horizon 6
# Out:
# Loading from models/vel_ee/model_registrar-12.pt
# Loaded!
#
# -- Preparing Node Graph
# 100% 71/71 [00:02<00:00, 25.79it/s]
# Prediction Horizon: 6
# -- Evaluating GMM Z Mode (Most Likely)
# 100% 71/71 [01:01<00:00,  1.15it/s]
# 1.0849839185139545
# -- Evaluating Full
#   0% 0/71 [00:00<?, ?it/s]tcmalloc: large alloc 2660352000 bytes == 0xcdd20000 @  0x7fe7a9587b6b 0x7fe7a95a7379 0x7fe74ecc5b4a 0x7fe74ecc75fa 0x7fe7513cd9fb 0x7fe7513e15cd 0x7fe751440df8 0x7fe75144163f 0x7fe7512e57e2 0x7fe751316ba6 0x7fe751285e0b 0x7fe75128780e 0x7fe752ebe8fd 0x7fe75128780e 0x7fe750e2bb40 0x7fe751350c79 0x7fe752dba9bd 0x7fe751288213 0x7fe750f242cd 0x7fe750f283bb 0x7fe750f28b1b 0x7fe751368e9f 0x7fe752dba3ea 0x7fe751380973 0x7fe799d77513 0x7fe799c6987e 0x50a7f5 0x50c1f4 0x507f24 0x509202 0x594b01
# tcmalloc: large alloc 2660352000 bytes == 0x7fe6716e4000 @  0x7fe7a9587b6b 0x7fe7a95a7379 0x7fe74ecc5b4a 0x7fe74ecc75fa 0x7fe7513cd9fb 0x7fe7513e15cd 0x7fe751440df8 0x7fe75144163f 0x7fe7512e57e2 0x7fe751316ba6 0x7fe751285e0b 0x7fe75128780e 0x7fe752ebe8fd 0x7fe75128780e 0x7fe750e2bb40 0x7fe751350c79 0x7fe752dba9bd 0x7fe751288213 0x7fe750f242cd 0x7fe750f2817d 0x7fe750f28b1b 0x7fe751368e9f 0x7fe752dba3ea 0x7fe751380973 0x7fe799d77513 0x7fe799c6987e 0x50a7f5 0x50c1f4 0x507f24 0x509202 0x594b01
# tcmalloc: large alloc 2660352000 bytes == 0x7fe63c930000 @  0x7fe7a9587b6b 0x7fe7a95a7379 0x7fe74ecc5b4a 0x7fe74ecc75fa 0x7fe7513cd9fb 0x7fe7513e15cd 0x7fe751440df8 0x7fe75144163f 0x7fe7512e57e2 0x7fe751316ba6 0x7fe751285e0b 0x7fe75128780e 0x7fe752ebe8fd 0x7fe75128780e 0x7fe750e2bb40 0x7fe751350c79 0x7fe752dba9bd 0x7fe751288213 0x7fe750f242cd 0x7fe750f283bb 0x7fe750f28b1b 0x7fe751368e9f 0x7fe752dba3ea 0x7fe751380973 0x7fe799d77513 0x7fe799c6987e 0x50a7f5 0x50c1f4 0x507f24 0x509202 0x594b01
# tcmalloc: large alloc 2660352000 bytes == 0x7fe569260000 @  0x7fe7a9587b6b 0x7fe7a95a7379 0x7fe74ecc5b4a 0x7fe74ecc75fa 0x7fe7513cd9fb 0x7fe7513e15cd 0x7fe751440df8 0x7fe75144163f 0x7fe7512e57e2 0x7fe751316ba6 0x7fe751285e0b 0x7fe75128780e 0x7fe752ebe8fd 0x7fe75128780e 0x7fe750e2bb40 0x7fe751350c79 0x7fe752dba9bd 0x7fe751288213 0x7fe750f242cd 0x7fe750f2817d 0x7fe750f28b1b 0x7fe751368e9f 0x7fe752dba3ea 0x7fe751380973 0x7fe799d77513 0x7fe799c6987e 0x50a7f5 0x50c1f4 0x507f24 0x509202 0x594b01
# tcmalloc: large alloc 2660352000 bytes == 0x7fe569260000 @  0x7fe7a9587b6b 0x7fe7a95a7379 0x7fe74ecc5b4a 0x7fe74ecc75fa 0x7fe7513cd9fb 0x7fe7513e15cd 0x7fe751440df8 0x7fe75144163f 0x7fe7512e57e2 0x7fe751316ba6 0x7fe751285e0b 0x7fe75128780e 0x7fe752ebe8fd 0x7fe75128780e 0x7fe750e2bb40 0x7fe751350c79 0x7fe752dba9bd 0x7fe751288213 0x7fe750f242cd 0x7fe750f283bb 0x7fe750f28b1b 0x7fe751368e9f 0x7fe752dba3ea 0x7fe751380973 0x7fe799d77513 0x7fe799c6987e 0x50a7f5 0x50c1f4 0x507f24 0x509202 0x594b01
# tcmalloc: large alloc 2660352000 bytes == 0x7fe607b7c000 @  0x7fe7a9587b6b 0x7fe7a95a7379 0x7fe74ecc5b4a 0x7fe74ecc75fa 0x7fe7513cd9fb 0x7fe7513e15cd 0x7fe751440df8 0x7fe75144163f 0x7fe7512e57e2 0x7fe751316ba6 0x7fe751285e0b 0x7fe75128780e 0x7fe752ebe8fd 0x7fe75128780e 0x7fe750e2bb40 0x7fe751350c79 0x7fe752dba9bd 0x7fe751288213 0x7fe750f242cd 0x7fe750f2817d 0x7fe750f28b1b 0x7fe751368e9f 0x7fe752dba3ea 0x7fe751380973 0x7fe799d77513 0x7fe799c6987e 0x50a7f5 0x50c1f4 0x507f24 0x509202 0x594b01
# tcmalloc: large alloc 2660352000 bytes == 0x7fe569260000 @  0x7fe7a9587b6b 0x7fe7a95a7379 0x7fe74ecc5b4a 0x7fe74ecc75fa 0x7fe7513cd9fb 0x7fe7513e15cd 0x7fe751440df8 0x7fe75144163f 0x7fe7512e57e2 0x7fe751316ba6 0x7fe751285e0b 0x7fe75128780e 0x7fe752ebe8fd 0x7fe75128780e 0x7fe750e2bb40 0x7fe751350c79 0x7fe752dba9bd 0x7fe751288213 0x7fe750f242cd 0x7fe750f283bb 0x7fe750f28b1b 0x7fe751368e9f 0x7fe752dba3ea 0x7fe751380973 0x7fe799d77513 0x7fe799c6987e 0x50a7f5 0x50c1f4 0x507f24 0x509202 0x594b01
# tcmalloc: large alloc 2660352000 bytes == 0x7fe607b7c000 @  0x7fe7a9587b6b 0x7fe7a95a7379 0x7fe74ecc5b4a 0x7fe74ecc75fa 0x7fe7513cd9fb 0x7fe7513e15cd 0x7fe751440df8 0x7fe75144163f 0x7fe7512e57e2 0x7fe751316ba6 0x7fe751285e0b 0x7fe75128780e 0x7fe752ebe8fd 0x7fe75128780e 0x7fe750e2bb40 0x7fe751350c79 0x7fe752dba9bd 0x7fe751288213 0x7fe750f242cd 0x7fe750f2817d 0x7fe750f28b1b 0x7fe751368e9f 0x7fe752dba3ea 0x7fe751380973 0x7fe799d77513 0x7fe799c6987e 0x50a7f5 0x50c1f4 0x507f24 0x509202 0x594b01
#   3% 2/71 [01:25<50:09, 43.62s/it]tcmalloc: large alloc 5114880000 bytes == 0x7fe56d3b8000 @  0x7fe7a9587b6b 0x7fe7a95a7379 0x7fe74ecc5b4a 0x7fe74ecc75fa 0x7fe7513cd9fb 0x7fe7513e15cd 0x7fe751440df8 0x7fe75144163f 0x7fe7512e57e2 0x7fe751316ba6 0x7fe751285e0b 0x7fe75128780e 0x7fe752ebe8fd 0x7fe75128780e 0x7fe750e2bb40 0x7fe751350c79 0x7fe752dba9bd 0x7fe751288213 0x7fe750f242cd 0x7fe750f283bb 0x7fe750f28b1b 0x7fe751368e9f 0x7fe752dba3ea 0x7fe751380973 0x7fe799d77513 0x7fe799c6987e 0x50a7f5 0x50c1f4 0x507f24 0x509202 0x594b01
# tcmalloc: large alloc 5114880000 bytes == 0x7fe4303b2000 @  0x7fe7a9587b6b 0x7fe7a95a7379 0x7fe74ecc5b4a 0x7fe74ecc75fa 0x7fe7513cd9fb 0x7fe7513e15cd 0x7fe751440df8 0x7fe75144163f 0x7fe7512e57e2 0x7fe751316ba6 0x7fe751285e0b 0x7fe75128780e 0x7fe752ebe8fd 0x7fe75128780e 0x7fe750e2bb40 0x7fe751350c79 0x7fe752dba9bd 0x7fe751288213 0x7fe750f242cd 0x7fe750f2817d 0x7fe750f28b1b 0x7fe751368e9f 0x7fe752dba3ea 0x7fe751380973 0x7fe799d77513 0x7fe799c6987e 0x50a7f5 0x50c1f4 0x507f24 0x509202 0x594b01
# tcmalloc: large alloc 5114880000 bytes == 0x7fe56d3b8000 @  0x7fe7a9587b6b 0x7fe7a95a7379 0x7fe74ecc5b4a 0x7fe74ecc75fa 0x7fe7513cd9fb 0x7fe7513e15cd 0x7fe751440df8 0x7fe75144163f 0x7fe7512e57e2 0x7fe751316ba6 0x7fe751285e0b 0x7fe75128780e 0x7fe752ebe8fd 0x7fe75128780e 0x7fe750e2bb40 0x7fe751350c79 0x7fe752dba9bd 0x7fe751288213 0x7fe750f242cd 0x7fe750f283bb 0x7fe750f28b1b 0x7fe751368e9f 0x7fe752dba3ea 0x7fe751380973 0x7fe799d77513 0x7fe799c6987e 0x50a7f5 0x50c1f4 0x507f24 0x509202 0x594b01
# tcmalloc: large alloc 5114880000 bytes == 0x7fe299bca000 @  0x7fe7a9587b6b 0x7fe7a95a7379 0x7fe74ecc5b4a 0x7fe74ecc75fa 0x7fe7513cd9fb 0x7fe7513e15cd 0x7fe751440df8 0x7fe75144163f 0x7fe7512e57e2 0x7fe751316ba6 0x7fe751285e0b 0x7fe75128780e 0x7fe752ebe8fd 0x7fe75128780e 0x7fe750e2bb40 0x7fe751350c79 0x7fe752dba9bd 0x7fe751288213 0x7fe750f242cd 0x7fe750f2817d 0x7fe750f28b1b 0x7fe751368e9f 0x7fe752dba3ea 0x7fe751380973 0x7fe799d77513 0x7fe799c6987e 0x50a7f5 0x50c1f4 0x507f24 0x509202 0x594b01
# tcmalloc: large alloc 5114880000 bytes == 0x7fe56d3b8000 @  0x7fe7a9587b6b 0x7fe7a95a7379 0x7fe74ecc5b4a 0x7fe74ecc75fa 0x7fe7513cd9fb 0x7fe7513e15cd 0x7fe751440df8 0x7fe75144163f 0x7fe7512e57e2 0x7fe751316ba6 0x7fe751285e0b 0x7fe75128780e 0x7fe752ebe8fd 0x7fe75128780e 0x7fe750e2bb40 0x7fe751350c79 0x7fe752dba9bd 0x7fe751288213 0x7fe750f242cd 0x7fe750f283bb 0x7fe750f28b1b 0x7fe751368e9f 0x7fe752dba3ea 0x7fe751380973 0x7fe799d77513 0x7fe799c6987e 0x50a7f5 0x50c1f4 0x507f24 0x509202 0x594b01
# tcmalloc: large alloc 5114880000 bytes == 0x7fe299bca000 @  0x7fe7a9587b6b 0x7fe7a95a7379 0x7fe74ecc5b4a 0x7fe74ecc75fa 0x7fe7513cd9fb 0x7fe7513e15cd 0x7fe751440df8 0x7fe75144163f 0x7fe7512e57e2 0x7fe751316ba6 0x7fe751285e0b 0x7fe75128780e 0x7fe752ebe8fd 0x7fe75128780e 0x7fe750e2bb40 0x7fe751350c79 0x7fe752dba9bd 0x7fe751288213 0x7fe750f242cd 0x7fe750f2817d 0x7fe750f28b1b 0x7fe751368e9f 0x7fe752dba3ea 0x7fe751380973 0x7fe799d77513 0x7fe799c6987e 0x50a7f5 0x50c1f4 0x507f24 0x509202 0x594b01
#  10% 7/71 [06:14<1:00:34, 56.79s/it]tcmalloc: large alloc 6018048000 bytes == 0x7fe299bca000 @  0x7fe7a9587b6b 0x7fe7a95a7379 0x7fe74ecc5b4a 0x7fe74ecc75fa 0x7fe7513cd9fb 0x7fe7513e15cd 0x7fe751440df8 0x7fe75144163f 0x7fe7512e57e2 0x7fe751316ba6 0x7fe751285e0b 0x7fe75128780e 0x7fe752ebe8fd 0x7fe75128780e 0x7fe750e2bb40 0x7fe751350c79 0x7fe752dba9bd 0x7fe751288213 0x7fe750f242cd 0x7fe750f283bb 0x7fe750f28b1b 0x7fe751368e9f 0x7fe752dba3ea 0x7fe751380973 0x7fe799d77513 0x7fe799c6987e 0x50a7f5 0x50c1f4 0x507f24 0x509202 0x594b01
#  18% 13/71 [12:47<52:48, 54.63s/it]  tcmalloc: large alloc 6343680000 bytes == 0x7fe5694d0000 @  0x7fe7a9587b6b 0x7fe7a95a7379 0x7fe74ecc5b4a 0x7fe74ecc75fa 0x7fe7513cd9fb 0x7fe7513e15cd 0x7fe751440df8 0x7fe75144163f 0x7fe7512e57e2 0x7fe751316ba6 0x7fe751285e0b 0x7fe75128780e 0x7fe752ebe8fd 0x7fe75128780e 0x7fe750e2bb40 0x7fe751350c79 0x7fe752dba9bd 0x7fe751288213 0x7fe750f242cd 0x7fe750f283bb 0x7fe750f28b1b 0x7fe751368e9f 0x7fe752dba3ea 0x7fe751380973 0x7fe799d77513 0x7fe799c6987e 0x50a7f5 0x50c1f4 0x507f24 0x509202 0x594b01
# ^C

# %% [markdown]
# ## Load nuScenes SDK and data

# %%
nuScenes_data_path = './v1.0-mini'
nuScenes_devkit_path = './devkit/python-sdk/'
sys.path.append(nuScenes_devkit_path)
from nuscenes.map_expansion.map_api import NuScenesMap
nusc_map = NuScenesMap(dataroot=nuScenes_data_path, map_name='boston-seaport')

# %%
line_colors = ['#375397','#80CBE5','#ABCB51','#F05F78', '#C8B0B0']

# %% [markdown]
# # Map Encoding Demo

# %%
with open('../processed/nuScenes_train_mini_full.pkl', 'rb') as f:
    eval_env = dill.load(f, encoding='latin1')
eval_scenes = eval_env.scenes

# %%
ph = 6
log_dir = './models'

# %%
model_dir = os.path.join(log_dir, 'int_ee_me') 
eval_stg, hyp = load_model(model_dir, eval_env, ts=12)
# Out:
# Loading from ./models/int_ee_me/model_registrar-12.pt
# Loaded!

# %%
scene = eval_scenes[1]
print("scene name: " + scene.name)
print("timesteps : " + str(scene.timesteps))
print("x_min     : " + str(scene.x_min))
print("y_min     : " + str(scene.y_min))
# scene.nodes[1].data.data
# Out:
# scene name: 553
# timesteps : 40
# x_min     : 1132.0
# y_min     : 964.0

# %%
# Define ROI in nuScenes Map
# x_min = 773.0
# x_max = 1100.0
# y_min = 1231.0
# y_max = 1510.0

x_min = 1132.0
x_max = 1300.0
y_min = 964.0
y_max = 1200.0

# %%
layers = ['drivable_area',
          'road_segment',
          'lane',
          'ped_crossing',
          'walkway',
          'stop_line',
          'road_divider',
          'lane_divider']

# %% [markdown]
# ## Prediction including Map Encoding

# %%
ph = 6
with torch.no_grad():
    timestep = np.array([2])
    predictions = eval_stg.predict(scene,
                                   timestep,
                                   ph,
                                   num_samples=500)

    predictions_mm = eval_stg.predict(scene,
                                      timestep,
                                      ph,
                                      num_samples=1,
                                      z_mode=True,
                                      gmm_mode=True)

    # Plot predicted timestep for random scene in map
    my_patch = (x_min, y_min, x_max, y_max)
    fig, ax = nusc_map.render_map_patch(my_patch, layers, figsize=(10, 10), alpha=0.1, render_egoposes_range=False)

    ax.plot([], [], 'ko-',
            zorder=620,
            markersize=4,
            linewidth=2, alpha=0.7, label='Ours (MM)')

    ax.plot([],
            [],
            'w--o', label='Ground Truth',
            linewidth=3,
            path_effects=[pe.Stroke(linewidth=4, foreground='k'), pe.Normal()])

#     plot_vehicle_nice(ax,
#                       predictions,
#                       scene.dt,
#                       max_hl=10,
#                       ph=ph,
#                       map=None, x_min=x_min, y_min=y_min)

#     plot_vehicle_mm(ax,
#                     predictions_mm,
#                     scene.dt,
#                     max_hl=10,
#                     ph=ph,
#                     map=None, x_min=x_min, y_min=y_min)

#     ax.set_ylim((1385, 1435))
#     ax.set_xlim((850, 900))
    ax.set_ylim((1100, 1300))
    ax.set_xlim((900, 1100))
    leg = ax.legend(loc='upper right', fontsize=20, frameon=True)
    ax.axis('off')
    for lh in leg.legendHandles:
        lh.set_alpha(.5)
    ax.get_legend().remove()
    fig.show()
    fig.savefig('plots/qual_nuScenes_map_pos.pdf', dpi=300, bbox_inches='tight')
# Out:
# /home/tkil/miniconda3/envs/trajectron++/lib/python3.6/site-packages/ipykernel_launcher.py:54: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.

# %% [markdown]
# ## Prediction without Map Encoding

# %%
model_dir = os.path.join(log_dir, 'int_ee') 
eval_stg_nm, hyp = load_model(model_dir, eval_env, ts=12)
# Out:
# Loading from ./models/int_ee/model_registrar-12.pt
# Loaded!

# %%
ph = 6
with torch.no_grad():
    timestep = np.array([2])
    predictions = eval_stg_nm.predict(scene,
                                   timestep,
                                   ph,
                                   num_samples=500)

    predictions_mm = eval_stg_nm.predict(scene,
                                      timestep,
                                      ph,
                                      num_samples=1,
                                      z_mode=True,
                                      gmm_mode=True)

    # Plot predicted timestep for random scene in map
    my_patch = (x_min, y_min, x_max, y_max)
    fig, ax = nusc_map.render_map_patch(my_patch, layers, figsize=(10, 10), alpha=0.1, render_egoposes_range=False)

    ax.plot([], [], 'ko-',
            zorder=620,
            markersize=4,
            linewidth=2, alpha=0.7, label='Ours (MM)')

    ax.plot([],
            [],
            'w--o', label='Ground Truth',
            linewidth=3,
            path_effects=[pe.Stroke(linewidth=4, foreground='k'), pe.Normal()])

    plot_vehicle_nice(ax,
                      predictions,
                      scene.dt,
                      max_hl=10,
                      ph=ph,
                      map=None, x_min=x_min, y_min=y_min)

    plot_vehicle_mm(ax,
                    predictions_mm,
                    scene.dt,
                    max_hl=10,
                    ph=ph,
                    map=None, x_min=x_min, y_min=y_min)

    ax.set_ylim((1385, 1435))
    ax.set_xlim((850, 900))
    leg = ax.legend(loc='upper right', fontsize=20, frameon=True)
    ax.axis('off')
    for lh in leg.legendHandles:
        lh.set_alpha(.5)
    ax.get_legend().remove()
    fig.show()
    fig.savefig('plots/qual_nuScenes_no_map_pos.pdf', dpi=300, bbox_inches='tight')
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# /home/tkil/miniconda3/envs/trajectron++/lib/python3.6/site-packages/ipykernel_launcher.py:52: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.

# %% [markdown]
# ## Prediction using velocity output

# %%
model_dir = os.path.join(log_dir, 'vel_ee') 
eval_stg_vel, hyp = load_model(model_dir, eval_env, ts=12)
# Out:
# Loading from ./models/vel_ee/model_registrar-12.pt
# Loaded!

# %%
ph = 6
with torch.no_grad():
    timestep = np.array([2])
    predictions = eval_stg_vel.predict(scene,
                                   timestep,
                                   ph,
                                   num_samples=500)

    predictions_mm = eval_stg_vel.predict(scene,
                                      timestep,
                                      ph,
                                      num_samples=1,
                                      z_mode=True,
                                      gmm_mode=True)

    # Plot predicted timestep for random scene in map
    my_patch = (x_min, y_min, x_max, y_max)
    fig, ax = nusc_map.render_map_patch(my_patch, layers, figsize=(10, 10), alpha=0.1, render_egoposes_range=False)

    ax.plot([], [], 'ko-',
            zorder=620,
            markersize=4,
            linewidth=2, alpha=0.7, label='Ours (MM)')

    ax.plot([],
            [],
            'w--o', label='Ground Truth',
            linewidth=3,
            path_effects=[pe.Stroke(linewidth=4, foreground='k'), pe.Normal()])

    plot_vehicle_nice(ax,
                      predictions,
                      scene.dt,
                      max_hl=10,
                      ph=ph,
                      map=None, x_min=x_min, y_min=y_min)

    plot_vehicle_mm(ax,
                    predictions_mm,
                    scene.dt,
                    max_hl=10,
                    ph=ph,
                    map=None, x_min=x_min, y_min=y_min)

    ax.set_ylim((1385, 1435))
    ax.set_xlim((850, 900))
    leg = ax.legend(loc='upper right', fontsize=20, frameon=True)
    ax.axis('off')
    for lh in leg.legendHandles:
        lh.set_alpha(.5)
    ax.get_legend().remove()
    fig.show()
    fig.savefig('plots/qual_nuScenes_no_map_vel.pdf', dpi=300, bbox_inches='tight')
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# /home/tkil/miniconda3/envs/trajectron++/lib/python3.6/site-packages/ipykernel_launcher.py:52: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.

# %% [markdown]
# ## Prediction using velocity output and map

# %%
model_dir = os.path.join(log_dir, 'me_vel') 
eval_stg_vel_map, hyp = load_model(model_dir, eval_env, ts=12)
# Out:
# Loading from ./models/me_vel/model_registrar-12.pt
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-20-0ae8b7035584> in <module>
#       1 model_dir = os.path.join(log_dir, 'me_vel')
# ----> 2 eval_stg_vel_map, hyp = load_model(model_dir, eval_env, ts=12)
#
# /media/tkil/Code Disk/GIT/Trajectron-plus-plus/experiments/nuScenes/helper.py in load_model(model_dir, env, ts)
#      27 def load_model(model_dir, env, ts=3999):
#      28     model_registrar = ModelRegistrar(model_dir, 'cpu')
# ---> 29     model_registrar.load_models(ts)
#      30     with open(os.path.join(model_dir, 'config.json'), 'r') as config_json:
#      31         hyperparams = json.load(config_json)
#
# /media/tkil/Code Disk/GIT/Trajectron-plus-plus/trajectron/model/model_registrar.py in load_models(self, iter_num)
#      66         print('')
#      67         print('Loading from ' + save_path)
# ---> 68         self.model_dict = torch.load(save_path, map_location=self.device)
#      69         print('Loaded!')
#      70         print('')
#
# ~/miniconda3/envs/trajectron++/lib/python3.6/site-packages/torch/serialization.py in load(f, map_location, pickle_module, **pickle_load_args)
#     523         pickle_load_args['encoding'] = 'utf-8'
#     524
# --> 525     with _open_file_like(f, 'rb') as opened_file:
#     526         if _is_zipfile(opened_file):
#     527             with _open_zipfile_reader(f) as opened_zipfile:
#
# ~/miniconda3/envs/trajectron++/lib/python3.6/site-packages/torch/serialization.py in _open_file_like(name_or_buffer, mode)
#     210 def _open_file_like(name_or_buffer, mode):
#     211     if _is_path(name_or_buffer):
# --> 212         return _open_file(name_or_buffer, mode)
#     213     else:
#     214         if 'w' in mode:
#
# ~/miniconda3/envs/trajectron++/lib/python3.6/site-packages/torch/serialization.py in __init__(self, name, mode)
#     191 class _open_file(_opener):
#     192     def __init__(self, name, mode):
# --> 193         super(_open_file, self).__init__(open(name, mode))
#     194
#     195     def __exit__(self, *args):
#
# FileNotFoundError: [Errno 2] No such file or directory: './models/me_vel/model_registrar-12.pt'

# %%
ph = 6
with torch.no_grad():
    timestep = np.array([2])
    predictions = eval_stg_vel_map.predict(scene,
                                   timestep,
                                   ph,
                                   num_samples=500)

    predictions_mm = eval_stg_vel_map.predict(scene,
                                      timestep,
                                      ph,
                                      num_samples=1,
                                      z_mode=True,
                                      gmm_mode=True)

    # Plot predicted timestep for random scene in map
    my_patch = (x_min, y_min, x_max, y_max)
    fig, ax = nusc_map.render_map_patch(my_patch, layers, figsize=(10, 10), alpha=0.1, render_egoposes_range=False)

    ax.plot([], [], 'ko-',
            zorder=620,
            markersize=4,
            linewidth=2, alpha=0.7, label='Ours (MM)')

    ax.plot([],
            [],
            'w--o', label='Ground Truth',
            linewidth=3,
            path_effects=[pe.Stroke(linewidth=4, foreground='k'), pe.Normal()])

    plot_vehicle_nice(ax,
                      predictions,
                      scene.dt,
                      max_hl=10,
                      ph=ph,
                      map=None, x_min=x_min, y_min=y_min)

    plot_vehicle_mm(ax,
                    predictions_mm,
                    scene.dt,
                    max_hl=10,
                    ph=ph,
                    map=None, x_min=x_min, y_min=y_min)

    ax.set_ylim((1385, 1435))
    ax.set_xlim((850, 900))
    leg = ax.legend(loc='upper right', fontsize=20, frameon=True)
    ax.axis('off')
    for lh in leg.legendHandles:
        lh.set_alpha(.5)
    ax.get_legend().remove()
    fig.show()
    fig.savefig('plots/qual_nuScenes_map_vel.pdf', dpi=300, bbox_inches='tight')

# %%
my_patch = (0, 0, 1, 1)
fig, ax = nusc_map.render_map_patch(my_patch, layers, figsize=(1, 1), alpha=0.1, render_egoposes_range=False)
ax.plot([], [], 'ko',
            zorder=620,
            markersize=4,
            linewidth=2, alpha=0.7, label='Ours (ML)')

ax.plot([],
        [],
        'w--o', label='Ground Truth',
        linewidth=3,
        path_effects=[pe.Stroke(linewidth=4, foreground='k'), pe.Normal()])
leg = ax.legend(loc='upper left', fontsize=30, frameon=True)
for lh in leg.legendHandles:
    lh.set_alpha(.5)
ax.axis('off')
ax.grid('off')
fig.savefig('plots/qual_nuScenes_legend.pdf', dpi=300, bbox_inches='tight')
